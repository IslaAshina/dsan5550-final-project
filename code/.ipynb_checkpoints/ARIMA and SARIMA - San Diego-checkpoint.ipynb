# %%
from codecarbon import EmissionsTracker

# Set up the emissions tracker
tracker = EmissionsTracker()
# Out:
# [codecarbon INFO @ 22:29:48] [setup] RAM Tracking...
# [codecarbon INFO @ 22:29:48] [setup] GPU Tracking...
# [codecarbon INFO @ 22:29:48] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 22:29:48] [setup] CPU Tracking...
# [codecarbon WARNING @ 22:29:48] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 22:29:50] We saw that you have a 12th Gen Intel(R) Core(TM) i7-12700H but we don't know it. Please contact us.
# [codecarbon INFO @ 22:29:50] CPU Model on constant consumption mode: 12th Gen Intel(R) Core(TM) i7-12700H
# [codecarbon INFO @ 22:29:50] >>> Tracker's metadata:
# [codecarbon INFO @ 22:29:50]   Platform system: Windows-10-10.0.22000-SP0
# [codecarbon INFO @ 22:29:50]   Python version: 3.8.5
# [codecarbon INFO @ 22:29:50]   CodeCarbon version: 2.3.5
# [codecarbon INFO @ 22:29:50]   Available RAM : 15.692 GB
# [codecarbon INFO @ 22:29:50]   CPU count: 20
# [codecarbon INFO @ 22:29:50]   CPU model: 12th Gen Intel(R) Core(TM) i7-12700H
# [codecarbon INFO @ 22:29:50]   GPU count: 1
# [codecarbon INFO @ 22:29:50]   GPU model: 1 x NVIDIA GeForce RTX 3070 Ti Laptop GPU

# %%
# Start tracking
tracker.start()

# %%
import pandas as pd

# Load the dataset
file_path = '../data/Water Level - San Diego - v2.csv'
water_data = pd.read_csv(file_path)

# Display the first few rows of the dataframe and its structure
water_data.head(), water_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10944 entries, 0 to 10943
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10944 non-null  object
#  1   Time (GMT)      10944 non-null  object
#  2   Predicted (ft)  10944 non-null  float64
#  3   Verified (ft)   10944 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 342.1+ KB
# (       Date Time (GMT)  Predicted (ft)  Verified (ft)
#  0  1/1/2023       0:00           3.152           3.48
#  1  1/1/2023       1:00           3.354           3.78
#  2  1/1/2023       2:00           3.245           3.72
#  3  1/1/2023       3:00           2.906           3.36
#  4  1/1/2023       4:00           2.439           3.06,
#  None)

# %% [markdown]
# ### Step 1: Load and Inspect the Data
# The dataset contains the following columns:
#
# - Date: The date of the observation.
# - Time (GMT): The hourly time of the observation in GMT.
# - Predicted (ft): NOAA's predicted water level in feet.
# - Verified (ft): The actual verified water level in feet.
#
# The data is formatted with separate columns for date and time, and there are no missing values in the dataset. The next step is to preprocess the data:
#
# ### Step 2: Preprocess the Data
# 1. Combine Date and Time: We'll merge the 'Date' and 'Time (GMT)' columns into a single datetime column, which will help in time series analysis.
# 2. Set Datetime as Index: We will set this new datetime column as the index of the DataFrame, facilitating easier slicing and dicing of the data for time series forecasting.
# 3. Focus on Relevant Data: Since you are interested in predicting the 'Verified (ft)' column, we'll focus on this as our main variable.

# %%
import matplotlib.pyplot as plt

# Combine Date and Time columns into a single datetime column
water_data['Datetime'] = pd.to_datetime(water_data['Date'] + ' ' + water_data['Time (GMT)'])
water_data.set_index('Datetime', inplace=True)

# Dropping the original Date and Time columns as they are no longer needed
water_data.drop(columns=['Date', 'Time (GMT)'], inplace=True)

# %%
# Focus on the 'Verified (ft)' column
water_level_data = water_data[['Verified (ft)']]

# Show the first few rows of the new DataFrame and the overall index type to confirm changes
water_level_data.head(), water_level_data.index
# Out:
# (                     Verified (ft)
#  Datetime
#  2023-01-01 00:00:00           3.48
#  2023-01-01 01:00:00           3.78
#  2023-01-01 02:00:00           3.72
#  2023-01-01 03:00:00           3.36
#  2023-01-01 04:00:00           3.06,
#  DatetimeIndex(['2023-01-01 00:00:00', '2023-01-01 01:00:00',
#                 '2023-01-01 02:00:00', '2023-01-01 03:00:00',
#                 '2023-01-01 04:00:00', '2023-01-01 05:00:00',
#                 '2023-01-01 06:00:00', '2023-01-01 07:00:00',
#                 '2023-01-01 08:00:00', '2023-01-01 09:00:00',
#                 ...
#                 '2024-03-31 14:00:00', '2024-03-31 15:00:00',
#                 '2024-03-31 16:00:00', '2024-03-31 17:00:00',
#                 '2024-03-31 18:00:00', '2024-03-31 19:00:00',
#                 '2024-03-31 20:00:00', '2024-03-31 21:00:00',
#                 '2024-03-31 22:00:00', '2024-03-31 23:00:00'],
#                dtype='datetime64[ns]', name='Datetime', length=10944, freq=None))

# %% [markdown]
# The preprocessing steps are now complete:
#
# - The 'Date' and 'Time (GMT)' columns have been merged into a single 'DateTime' column.
# - This 'DateTime' column is now set as the index of the DataFrame, which is structured for time series analysis focusing on the 'Verified (ft)' water level measurements.
#
# ### Step 3: Visualize the Data
# To better understand any underlying trends, seasonality, or other patterns in the water level data, let's visualize it. This can provide insights into how to best model the data and whether there are specific times of year or other factors that heavily influence the water levels. We'll create a time series plot of the 'Verified (ft)' water levels.
#
# - Seasonal Decomposition: We will perform a seasonal decomposition to visually inspect the trends, seasonality, and residuals.

# %%
import matplotlib.pyplot as plt

# Plotting the Verified Water Levels
plt.figure(figsize=(14, 7))
plt.plot(water_data.index, water_data['Verified (ft)'], label='Verified Water Level', color='blue', alpha=0.6)
plt.plot(water_data.index, water_data['Predicted (ft)'], label='Predicted Water Level', color='red', alpha=0.6)
plt.title('Verified vs Predicted Water Levels over Time')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.show()

# %%
water_data
# Out:
#                      Predicted (ft)  Verified (ft)
# Datetime
# 2023-01-01 00:00:00           3.152           3.48
# 2023-01-01 01:00:00           3.354           3.78
# 2023-01-01 02:00:00           3.245           3.72
# 2023-01-01 03:00:00           2.906           3.36
# 2023-01-01 04:00:00           2.439           3.06
# ...                             ...            ...
# 2024-03-31 19:00:00           1.512           2.16
# 2024-03-31 20:00:00           1.882           2.49
# 2024-03-31 21:00:00           2.198           2.84
# 2024-03-31 22:00:00           2.411           3.15
# 2024-03-31 23:00:00           2.511           3.18
#
# [10944 rows x 2 columns]

# %% [markdown]
# The plot above displays the verified water levels over time from January 2023 to March 2024. It reveals some clear periodic fluctuations, which suggest a presence of seasonality in the data. Such patterns are critical for selecting the appropriate model and parameters for time series forecasting.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Seasonal decomposition of the original 'Verified (ft)' data
decomposition = seasonal_decompose(water_data['Verified (ft)'], model='additive', period=24)  # Assuming daily seasonality

# Plotting the seasonal decomposition components
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(15, 12))
decomposition.observed.plot(ax=ax1, title='Observed')
decomposition.trend.plot(ax=ax2, title='Trend')
decomposition.seasonal.plot(ax=ax3, title='Seasonal')
decomposition.resid.plot(ax=ax4, title='Residual')
plt.tight_layout()
plt.show()

# %% [markdown]
# The seasonal decomposition plots provide the following insights into the water level data:
#
# 1. Observed: This plot shows the actual water levels recorded over the time period, which includes all the fluctuations, trends, and seasonal variations.
# 2. Trend: This component smooths out the series to show a more general pattern in the data over time, ignoring short-term fluctuations. From the plot, you can observe how the water levels have varied in a more generalized way.
# 3. Seasonal: This plot reveals the daily cycle in the water levels. It shows consistent patterns occurring every 24 hours, which is crucial for understanding how water levels typically behave throughout a day.
# 4. Residual: These are the deviations from the model that includes both the trend and seasonal components. Ideally, the residuals should be random noise if the model is fitting well. Significant patterns in the residuals could indicate potential improvements in the model or the presence of additional influences not captured by the trend or seasonal components.

# %% [markdown]
# ### Step 4: Stationarity Check
# For ARIMA modeling, the time series data should be stationary. This means the statistical properties like mean and variance should not vary over time. Let's perform a stationarity test, specifically the Augmented Dickey-Fuller (ADF) test, to determine if the water level data needs differencing or any other transformations to make it stationary.

# %%
from statsmodels.tsa.stattools import adfuller

# Performing Augmented Dickey-Fuller test on the 'Verified (ft)' column
adf_result = adfuller(water_data['Verified (ft)'])

# Displaying ADF Test Results
adf_output = pd.Series(adf_result[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key, value in adf_result[4].items():
    adf_output[f'Critical Value ({key})'] = value

adf_output
# Out:
# Test Statistic                    -2.914049
# p-value                            0.043739
# #Lags Used                        39.000000
# Number of Observations Used    10904.000000
# Critical Value (1%)               -3.430950
# Critical Value (5%)               -2.861805
# Critical Value (10%)              -2.566911
# dtype: float64

# %% [markdown]
# The results from the Augmented Dickey-Fuller (ADF) test are as follows:
#
# - ADF Test Statistic: `−2.816`
# - p-value: `0.056`
#
# The test statistic is not less than the critical values at conventional significance levels (1%, 5%, 10%). This suggests that the null hypothesis of the ADF test (that the series possesses a unit root and is non-stationary) cannot be rejected at a 5% significance level, though it's quite borderline.
#
# ### Step 5: Differencing the Series
# Given that the series is nearly stationary but not conclusively so, we will first difference the series once and then check for stationarity again to confirm if it's adequate for ARIMA modeling.
#
# Let's proceed by differencing the series and then testing for stationarity again.

# %%
# Applying first order differencing to the 'Verified (ft)' column
water_data['Verified_diff'] = water_data['Verified (ft)'].diff()

# Dropping NaN values that result from differencing
water_data_diff = water_data.dropna()

# Re-performing the Augmented Dickey-Fuller test on the differenced data
adf_result_diff = adfuller(water_data_diff['Verified_diff'])

# Displaying ADF Test Results for differenced data
adf_output_diff = pd.Series(adf_result_diff[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key, value in adf_result_diff[4].items():
    adf_output_diff[f'Critical Value ({key})'] = value

adf_output_diff
# Out:
# Test Statistic                   -23.235068
# p-value                            0.000000
# #Lags Used                        39.000000
# Number of Observations Used    10903.000000
# Critical Value (1%)               -3.430950
# Critical Value (5%)               -2.861805
# Critical Value (10%)              -2.566911
# dtype: float64

# %% [markdown]
# The results from the Augmented Dickey-Fuller test on the differenced series are:
#
# - ADF Test Statistic: `−33.431`
# - p-value: `0.0`
#
# The test statistic is significantly less than the critical values for all common significance levels (1%, 5%, 10%). This indicates that the differenced series is stationary. Thus, one level of differencing is appropriate for modeling this data using an ARIMA model.
#
# ### Step 6: Model Selection and Fitting
# We will next use the AutoCorrelation Function (ACF) and Partial AutoCorrelation Function (PACF) plots to determine the order of the ARIMA model. These plots help identify the parameters (p, d, q):
#
# - p (AR term) can be estimated from the PACF.
# - d (differencing order) is 1, as we determined from the differencing step.
# - q (MA term) can be estimated from the ACF.
#
# Let's generate the ACF and PACF plots for the differenced data to help us select the best parameters for the ARIMA model. ​

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plotting the ACF and PACF for the differenced data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))
plot_acf(water_data_diff['Verified_diff'], lags=50, ax=ax1, title='Autocorrelation Function')
plot_pacf(water_data_diff['Verified_diff'], lags=50, ax=ax2, title='Partial Autocorrelation Function')
plt.tight_layout()
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# Differencing the series once
water_level_diff = water_data['Verified (ft)'].diff().dropna()

# Perform the Augmented Dickey-Fuller test on the differenced data
adf_result_diff = adfuller(water_level_diff)

# Extract and display the ADF test results for the differenced data
adf_test_statistic_diff = adf_result_diff[0]
p_value_diff = adf_result_diff[1]
critical_values_diff = adf_result_diff[4]

adf_test_statistic_diff, p_value_diff, critical_values_diff
# Out:
# (-23.235067534699525,
#  0.0,
#  {'1%': -3.430949911973261,
#   '5%': -2.8618051278244807,
#   '10%': -2.5669111224099344})

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plotting ACF and PACF
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Plot the ACF
plot_acf(water_level_diff, lags=50, ax=ax1)
ax1.set_title('Autocorrelation Function')

# Plot the PACF
plot_pacf(water_level_diff, lags=50, ax=ax2)
ax2.set_title('Partial Autocorrelation Function')

plt.tight_layout()
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ### Parameter Estimation from ACF and PACF Plots:
# - ACF Plot: Shows significant lags at the initial points and then it tapers off, suggesting potential MA components.
# - PACF Plot: Sharp cut-off after the first few lags, indicating potential AR components.
# ### Proposed ARIMA Model:
# - p (AR terms): The PACF plot shows significance at lag 1 primarily. This suggests setting `p=1`.
# - d (Differencing order): We already determined `d=1` from our stationarity analysis.
# - q (MA terms): The ACF plot shows a few significant lags, especially at lag 1 and somewhat at lag 2, suggesting `q=1` or `q=2`.
#
# Let's fit an ARIMA model with these parameters, `ARIMA(1,1,1)` and `ARIMA(1,1,2)`, to the water level data. We'll then forecast the water level for each hour on 04/01/2024. Let's proceed to fit the model and perform the forecast.

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit the ARIMA model
model = ARIMA(water_level_data, order=(1, 1, 1))
model_fit = model.fit()

# Forecast water levels
forecast_date = '2024-04-01'
forecast_hours = 24  # Number of hours in the day to forecast
forecast_result = model_fit.get_forecast(steps=forecast_hours)

# Extract forecast mean and confidence intervals
forecast_mean = forecast_result.predicted_mean
forecast_conf_int = forecast_result.conf_int()

forecast_mean, forecast_conf_int
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# (2024-04-01 00:00:00    3.062410
#  2024-04-01 01:00:00    2.963327
#  2024-04-01 02:00:00    2.879837
#  2024-04-01 03:00:00    2.809486
#  2024-04-01 04:00:00    2.750207
#  2024-04-01 05:00:00    2.700258
#  2024-04-01 06:00:00    2.658169
#  2024-04-01 07:00:00    2.622704
#  2024-04-01 08:00:00    2.592821
#  2024-04-01 09:00:00    2.567640
#  2024-04-01 10:00:00    2.546423
#  2024-04-01 11:00:00    2.528544
#  2024-04-01 12:00:00    2.513480
#  2024-04-01 13:00:00    2.500786
#  2024-04-01 14:00:00    2.490090
#  2024-04-01 15:00:00    2.481077
#  2024-04-01 16:00:00    2.473483
#  2024-04-01 17:00:00    2.467083
#  2024-04-01 18:00:00    2.461691
#  2024-04-01 19:00:00    2.457148
#  2024-04-01 20:00:00    2.453319
#  2024-04-01 21:00:00    2.450093
#  2024-04-01 22:00:00    2.447375
#  2024-04-01 23:00:00    2.445085
#  Freq: H, Name: predicted_mean, dtype: float64,
#                       lower Verified (ft)  upper Verified (ft)
#  2024-04-01 00:00:00             2.603469             3.521352
#  2024-04-01 01:00:00             1.672897             4.253756
#  2024-04-01 02:00:00             0.636038             5.123635
#  2024-04-01 03:00:00            -0.451323             6.070296
#  2024-04-01 04:00:00            -1.556308             7.056723
#  2024-04-01 05:00:00            -2.658857             8.059373
#  2024-04-01 06:00:00            -3.746471             9.062810
#  2024-04-01 07:00:00            -4.811400            10.056809
#  2024-04-01 08:00:00            -5.848989            11.034631
#  2024-04-01 09:00:00            -6.856654            11.991935
#  2024-04-01 10:00:00            -7.833204            12.926050
#  2024-04-01 11:00:00            -8.778396            13.835485
#  2024-04-01 12:00:00            -9.692619            14.719578
#  2024-04-01 13:00:00           -10.576681            15.578253
#  2024-04-01 14:00:00           -11.431659            16.411838
#  2024-04-01 15:00:00           -12.258786            17.220940
#  2024-04-01 16:00:00           -13.059383            18.006348
#  2024-04-01 17:00:00           -13.834801            18.768967
#  2024-04-01 18:00:00           -14.586385            19.509768
#  2024-04-01 19:00:00           -15.315455            20.229750
#  2024-04-01 20:00:00           -16.023280            20.929918
#  2024-04-01 21:00:00           -16.711075            21.611261
#  2024-04-01 22:00:00           -17.379993            22.274743
#  2024-04-01 23:00:00           -18.031121            22.921291)

# %%
# Extracting data for March 2024 for plotting context
march_2024_data = water_level_data['2024-03-01':'2024-03-31']

# Concatenate the March 2024 data with the forecast data for April 1st, 2024
combined_data = pd.concat([march_2024_data, forecast_mean])

# %%
# Plotting the results without confidence intervals due to previous error
plt.figure(figsize=(14, 7))
plt.plot(march_2024_data.index, march_2024_data['Verified (ft)'], label='Actual Verified Water Level (ft)', color='blue')
plt.plot(forecast_mean.index, forecast_mean, label='Forecasted Water Level (ft)', color='red', linestyle='--')
plt.title('Water Level Forecast vs Actual Data')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The ARIMA(1,1,1) model has provided the following forecast for the water levels on April 1st, 2024:
#
# - Predicted Mean Water Levels (ft): Values start from approximately 2.88 ft at midnight and slightly increase throughout the day, reaching about 3.00 ft by 11 PM.
# - Confidence Intervals: The forecast shows increasing uncertainty as time progresses, starting with a fairly tight confidence interval at midnight (from about 2.16 ft to 3.61 ft) and widening significantly towards the end of the day (from about -14.09 ft to 20.10 ft). This wide range indicates increasing uncertainty in the forecast as the lead time increases.

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit the ARIMA model
model = ARIMA(water_level_data, order=(1, 1, 2))
model_fit = model.fit()

# Forecast water levels
forecast_date = '2024-04-01'
forecast_hours = 24  # Number of hours in the day to forecast
forecast_result = model_fit.get_forecast(steps=forecast_hours)

# Extract forecast mean and confidence intervals
forecast_mean = forecast_result.predicted_mean
forecast_conf_int = forecast_result.conf_int()

forecast_mean, forecast_conf_int
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# (2024-04-01 00:00:00    2.975919
#  2024-04-01 01:00:00    2.734364
#  2024-04-01 02:00:00    2.546629
#  2024-04-01 03:00:00    2.400721
#  2024-04-01 04:00:00    2.287322
#  2024-04-01 05:00:00    2.199188
#  2024-04-01 06:00:00    2.130691
#  2024-04-01 07:00:00    2.077456
#  2024-04-01 08:00:00    2.036081
#  2024-04-01 09:00:00    2.003925
#  2024-04-01 10:00:00    1.978933
#  2024-04-01 11:00:00    1.959509
#  2024-04-01 12:00:00    1.944413
#  2024-04-01 13:00:00    1.932681
#  2024-04-01 14:00:00    1.923563
#  2024-04-01 15:00:00    1.916476
#  2024-04-01 16:00:00    1.910968
#  2024-04-01 17:00:00    1.906687
#  2024-04-01 18:00:00    1.903360
#  2024-04-01 19:00:00    1.900775
#  2024-04-01 20:00:00    1.898765
#  2024-04-01 21:00:00    1.897203
#  2024-04-01 22:00:00    1.895989
#  2024-04-01 23:00:00    1.895046
#  Freq: H, Name: predicted_mean, dtype: float64,
#                       lower Verified (ft)  upper Verified (ft)
#  2024-04-01 00:00:00             2.581772             3.370067
#  2024-04-01 01:00:00             1.536447             3.932282
#  2024-04-01 02:00:00             0.305680             4.787577
#  2024-04-01 03:00:00            -0.946706             5.748147
#  2024-04-01 04:00:00            -2.172726             6.747370
#  2024-04-01 05:00:00            -3.352165             7.750542
#  2024-04-01 06:00:00            -4.476882             8.738265
#  2024-04-01 07:00:00            -5.544839             9.699750
#  2024-04-01 08:00:00            -6.557195            10.629357
#  2024-04-01 09:00:00            -7.516747            11.524596
#  2024-04-01 10:00:00            -8.427054            12.384920
#  2024-04-01 11:00:00            -9.291935            13.210954
#  2024-04-01 12:00:00           -10.115191            14.004018
#  2024-04-01 13:00:00           -10.900446            14.765808
#  2024-04-01 14:00:00           -11.651072            15.498197
#  2024-04-01 15:00:00           -12.370157            16.203109
#  2024-04-01 16:00:00           -13.060501            16.882437
#  2024-04-01 17:00:00           -13.724624            17.537998
#  2024-04-01 18:00:00           -14.364785            18.171505
#  2024-04-01 19:00:00           -14.983004            18.784553
#  2024-04-01 20:00:00           -15.581088            19.378618
#  2024-04-01 21:00:00           -16.160649            19.955055
#  2024-04-01 22:00:00           -16.723127            20.515106
#  2024-04-01 23:00:00           -17.269812            21.059903)

# %%
# Extracting data for March 2024 for plotting context
march_2024_data = water_level_data['2024-03-01':'2024-03-31']

# Concatenate the March 2024 data with the forecast data for April 1st, 2024
combined_data = pd.concat([march_2024_data, forecast_mean])

# %%
# Plotting the results without confidence intervals due to previous error
plt.figure(figsize=(14, 7))
plt.plot(march_2024_data.index, march_2024_data['Verified (ft)'], label='Actual Verified Water Level (ft)', color='blue')
plt.plot(forecast_mean.index, forecast_mean, label='Forecasted Water Level (ft)', color='red', linestyle='--')
plt.title('Water Level Forecast vs Actual Data')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The ARIMA(1,1,2) model has provided the following forecast for the water levels on April 1st, 2024:
#
# - Predicted Mean Water Levels (ft): Values start from approximately 2.83 ft at midnight and slightly decrease throughout the day, reaching about 2.63 ft by 11 PM.
# - Confidence Intervals: The forecast shows increasing uncertainty as time progresses, starting with a fairly tight confidence interval at midnight (from about 2.20 ft to 3.47 ft) and widening significantly towards the end of the day (from about -15.00 ft to 20.26 ft). This wide range indicates increasing uncertainty in the forecast as the lead time increases.

# %% [markdown]
# The seasonal decomposition mentioned before provided a few insights that could be useful for refining the ARIMA prediction:
#
# 1. Strong Seasonality: The clear daily pattern observed in the seasonal component indicates that the data has a strong seasonal cycle every 24 hours. This suggests incorporating seasonal differencing in the ARIMA model (making it a SARIMA model) could improve the prediction accuracy.
# 2. Trend Stability: The trend component looked fairly stable, suggesting that our choice of differencing (d=1) was appropriate to make the data stationary. However, if there are any long-term trends observed closer to your forecast period, those might need to be revisited.
# 3. Residual Analysis: Ideally, the residuals should be noise-like. If there are significant patterns or outliers in the residuals, it indicates that the model may be missing some information. Checking the residuals closer to the forecast period can give clues about potential model misspecification.

# %%
# Load the future data provided
future_data_path = '../data/future data - San Diego.csv'
future_data = pd.read_csv(future_data_path)

# Display the first few rows of the future data and its info
future_data.head(), future_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            24 non-null     object
#  1   Time (GMT)      24 non-null     object
#  2   Predicted (ft)  24 non-null     float64
#  3   Verified (ft)   24 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 896.0+ bytes
# (       Date Time (GMT)  Predicted (ft)  Verified (ft)
#  0  4/1/2024       0:00           2.558           3.16
#  1  4/1/2024       1:00           2.640           3.27
#  2  4/1/2024       2:00           2.809           3.33
#  3  4/1/2024       3:00           3.071           3.57
#  4  4/1/2024       4:00           3.423           3.95,
#  None)

# %% [markdown]
# The future data for April 1st, 2024, has been successfully loaded and includes the following columns:
#
# - Date: Specifies the date for each entry.
# - Time (GMT): Specifies the hourly time.
# - Predicted (ft): NOAA's prediction for the water level at each hour.
# - Verified (ft): The actual verified water level at each hour.
#
# The data includes both predicted and verified water levels for every hour of April 1st, 2024. This will allow us to compare these actual verified values with our ARIMA model's forecasts.
#
# Let's proceed by comparing our ARIMA forecasts with the actual verified water levels to evaluate the model's accuracy and see if any adjustments based on the future data are necessary. I will plot both the forecasted and actual verified water levels for visual comparison

# %%
# Preprocess future data: Combine Date and Time into a datetime index
future_data['DateTime'] = pd.to_datetime(future_data['Date'] + ' ' + future_data['Time (GMT)'])
future_data.set_index('DateTime', inplace=True)

# Extract the verified water levels for April 1st, 2024 from the future data
actual_april_1_2024 = future_data['Verified (ft)']

# Plotting the forecasted results with actual verified data for April 1st, 2024
plt.figure(figsize=(14, 7))
plt.plot(forecast_mean.index, forecast_mean, label='ARIMA Forecasted Water Level (ft)', color='red', linestyle='--')
plt.plot(actual_april_1_2024.index, actual_april_1_2024, label='Actual Verified Water Level (ft)', color='blue')
plt.title('ARIMA Forecast vs Actual Verified Water Levels on April 1, 2024')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The plot above displays both the ARIMA model's forecasted water levels and the actual verified water levels for April 1st, 2024.
#
# ### Observations from the Comparison:
# - General Trend: The ARIMA forecast appears to capture the general rising trend of the water levels throughout the day, which is a good indication of the model's effectiveness.
# - Magnitude of Predictions: The forecasted levels seem to consistently underestimate the actual verified water levels, suggesting that the model might benefit from adjustments. This underestimation could be due to missing external factors or a need to incorporate the observed seasonality more explicitly in the model.
# ### Potential Adjustments:
# 1. Seasonal ARIMA (SARIMA): Given the strong daily seasonality observed earlier, employing a Seasonal ARIMA model might provide a better fit by explicitly modeling this aspect.
# 2. Model Parameters: Revisiting the model parameters (p, d, q) and adding seasonal parameters (P, D, Q) might help capture the seasonal fluctuations more accurately.
# 3. External Factors: If there are known external factors influencing water levels (e.g., tidal forces, weather conditions), incorporating these into the model could improve accuracy.

# %% [markdown]
# Using a Seasonal ARIMA (SARIMA) model is an effective way to account for and leverage the periodic fluctuations in data that exhibits strong seasonal patterns, such as the daily seasonality observed in your water level data. A SARIMA model extends the ARIMA model by adding seasonal terms, which allows it to capture both the non-seasonal and seasonal aspects of the time series.
#
# ### Components of a SARIMA Model
# A SARIMA model is typically denoted as SARIMA(p, d, q)(P, D, Q)[m], where:
#
# - `p,d,q` are the non-seasonal parameters for autoregression, differencing, and moving average components, respectively.
#
# - `P,D,Q` are the seasonal components of the model, mirroring the non-seasonal components but applied on the seasonality cycle.
#
# - `m` is the length of the seasonal cycle. In this case, `m=24` hours based on daily seasonality.
#
# ### Steps to Implement SARIMA:
# 1. Model Specification: Based on the initial analysis and seasonal decomposition, define the initial parameters for the SARIMA model.
# 2. Parameter Estimation: Use tools like grid search or ACF and PACF plots of the seasonal differenced series to refine the seasonal parameters.
# 3. Model Fitting: Fit the SARIMA model to your historical data.
# 4. Diagnostics: Check the residuals of the fitted model to ensure they resemble white noise (no pattern), indicating a good fit.
# 5. Forecasting: Use the model to make forecasts for the desired future periods.
# 6. Validation: Compare the SARIMA forecasts against actual data or hold-out data to validate the model's performance.
#
# Let's begin by specifying a SARIMA model based on the earlier ARIMA(1,1,1) and incorporating a seasonal component. We will then fit this model to your data, perform a forecast, and check the accuracy. We can start with some common settings for the seasonal part, like (1,1,1,24), and adjust as needed based on the model's performance.

# %% [markdown]
# ##### Case 1: SARIMA(1,1,1,24)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Fit the SARIMA model
sarima_model = SARIMAX(water_level_data['Verified (ft)'],
                       order=(1, 1, 1),
                       seasonal_order=(1, 1, 1, 24),
                       enforce_stationarity=False,
                       enforce_invertibility=False)
sarima_model_fit = sarima_model.fit(disp=False)

# Forecast using the SARIMA model for April 1, 2024
sarima_forecast_result = sarima_model_fit.get_forecast(steps=24)

# Extract forecast mean and confidence intervals
sarima_forecast_mean = sarima_forecast_result.predicted_mean
sarima_forecast_conf_int = sarima_forecast_result.conf_int()

# Print the SARIMA predicted values
print("SARIMA Predicted Values:")
print(sarima_forecast_mean)
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# [codecarbon INFO @ 22:30:08] Energy consumed for RAM : 0.000025 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:30:09] Energy consumed for all GPUs : 0.000073 kWh. Total GPU Power : 16.958467986415997 W
# [codecarbon INFO @ 22:30:09] Energy consumed for all CPUs : 0.000186 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:30:09] 0.000285 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:30:24] Energy consumed for RAM : 0.000048 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:30:24] Energy consumed for all GPUs : 0.000148 kWh. Total GPU Power : 18.90706297385767 W
# [codecarbon INFO @ 22:30:24] Energy consumed for all CPUs : 0.000358 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:30:24] 0.000555 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:30:38] Energy consumed for RAM : 0.000069 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:30:40] Energy consumed for all GPUs : 0.000222 kWh. Total GPU Power : 19.839403108912602 W
# [codecarbon INFO @ 22:30:41] Energy consumed for all CPUs : 0.000538 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:30:41] 0.000829 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:30:54] Energy consumed for RAM : 0.000087 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:30:56] Energy consumed for all GPUs : 0.000312 kWh. Total GPU Power : 26.46014920713368 W
# [codecarbon INFO @ 22:30:56] Energy consumed for all CPUs : 0.000695 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:30:56] 0.001094 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:31:09] Energy consumed for RAM : 0.000108 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:31:11] Energy consumed for all GPUs : 0.000376 kWh. Total GPU Power : 16.537939246973114 W
# [codecarbon INFO @ 22:31:12] Energy consumed for all CPUs : 0.000882 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:31:13] 0.001367 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:31:25] Energy consumed for RAM : 0.000126 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:31:28] Energy consumed for all GPUs : 0.000450 kWh. Total GPU Power : 22.457439440247462 W
# [codecarbon INFO @ 22:31:28] Energy consumed for all CPUs : 0.001038 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:31:28] 0.001614 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:31:41] Energy consumed for RAM : 0.000146 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:31:43] Energy consumed for all GPUs : 0.000536 kWh. Total GPU Power : 23.36447297037566 W
# [codecarbon INFO @ 22:31:43] Energy consumed for all CPUs : 0.001205 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:31:44] 0.001886 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:31:56] Energy consumed for RAM : 0.000164 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:31:58] Energy consumed for all GPUs : 0.000608 kWh. Total GPU Power : 21.486919847194386 W
# [codecarbon INFO @ 22:31:59] Energy consumed for all CPUs : 0.001373 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:32:00] 0.002145 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:32:15] Energy consumed for RAM : 0.000186 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:32:22] Energy consumed for all GPUs : 0.000712 kWh. Total GPU Power : 21.56082194811626 W
# [codecarbon INFO @ 22:32:22] Energy consumed for all CPUs : 0.001622 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:32:22] 0.002520 kWh of electricity used since the beginning.
# SARIMA Predicted Values:
# 2024-04-01 00:00:00    3.098576
# 2024-04-01 01:00:00    2.954817
# 2024-04-01 02:00:00    3.161822
# 2024-04-01 03:00:00    3.700855
# 2024-04-01 04:00:00    4.214263
# 2024-04-01 05:00:00    4.720630
# 2024-04-01 06:00:00    5.110254
# 2024-04-01 07:00:00    5.268247
# 2024-04-01 08:00:00    5.163240
# 2024-04-01 09:00:00    4.799347
# 2024-04-01 10:00:00    4.342579
# 2024-04-01 11:00:00    3.719000
# 2024-04-01 12:00:00    3.022613
# 2024-04-01 13:00:00    2.508960
# 2024-04-01 14:00:00    2.097600
# 2024-04-01 15:00:00    1.867224
# 2024-04-01 16:00:00    1.869212
# 2024-04-01 17:00:00    2.048356
# 2024-04-01 18:00:00    2.322538
# 2024-04-01 19:00:00    2.579273
# 2024-04-01 20:00:00    2.755848
# 2024-04-01 21:00:00    2.954064
# 2024-04-01 22:00:00    3.145631
# 2024-04-01 23:00:00    3.153683
# Freq: H, Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Calculate and print the RMSE, MAE, and R-squared metrics
rmse = np.sqrt(mean_squared_error(actual_april_1_2024, sarima_forecast_mean))
mae = mean_absolute_error(actual_april_1_2024, sarima_forecast_mean)
r2 = r2_score(actual_april_1_2024, sarima_forecast_mean)

print("RMSE: ", rmse)
print("MAE: ", mae)
print("R-squared: ", r2)
# Out:
# RMSE:  0.718901016750603
# MAE:  0.5783968863849194
# R-squared:  0.7505952159483398

# %%
# Plotting the SARIMA results with actual verified data for April 1st, 2024
plt.figure(figsize=(14, 7))
plt.plot(actual_april_1_2024.index, actual_april_1_2024, label='Actual Verified Water Level (ft)', color='blue')
plt.plot(sarima_forecast_mean.index, sarima_forecast_mean, label='SARIMA Forecasted Water Level (ft)', color='red', linestyle='--')
plt.fill_between(sarima_forecast_conf_int.index, sarima_forecast_conf_int.iloc[:, 0], sarima_forecast_conf_int.iloc[:, 1], color='red', alpha=0.3)
plt.title('SARIMA Forecast vs Actual Verified Water Levels on April 1, 2024')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Insights from the Plot (SARIMA(1,1,1,24)):
# - The model captures the overall trend in the water level data reasonably well.
# - The confidence intervals are wide, indicating a significant amount of uncertainty in the forecasts.
# - The forecasted values start off closely following the actual verified water levels but begin to diverge as time progresses.

# %% [markdown]
# ##### Case 2: SARIMA(1,1,2,24)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Fit the SARIMA model
sarima_model = SARIMAX(water_level_data['Verified (ft)'],
                       order=(1, 1, 2),
                       seasonal_order=(1, 1, 2, 24),
                       enforce_stationarity=False,
                       enforce_invertibility=False)
sarima_model_fit = sarima_model.fit(disp=False)

# Forecast using the SARIMA model for April 1, 2024
sarima_forecast_result = sarima_model_fit.get_forecast(steps=24)

# Extract forecast mean and confidence intervals
sarima_forecast_mean = sarima_forecast_result.predicted_mean
sarima_forecast_conf_int = sarima_forecast_result.conf_int()

# Print the SARIMA predicted values
print("SARIMA Predicted Values:")
print(sarima_forecast_mean)
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# [codecarbon INFO @ 22:32:32] Energy consumed for RAM : 0.000196 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:32:33] Energy consumed for all GPUs : 0.000782 kWh. Total GPU Power : 43.659155170812355 W
# [codecarbon INFO @ 22:32:34] Energy consumed for all CPUs : 0.001717 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:32:35] 0.002695 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:32:47] Energy consumed for RAM : 0.000215 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:32:48] Energy consumed for all GPUs : 0.000853 kWh. Total GPU Power : 21.629313011437635 W
# [codecarbon INFO @ 22:32:48] Energy consumed for all CPUs : 0.001873 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:32:49] 0.002942 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:33:02] Energy consumed for RAM : 0.000236 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:33:03] Energy consumed for all GPUs : 0.000934 kWh. Total GPU Power : 22.986573964704704 W
# [codecarbon INFO @ 22:33:04] Energy consumed for all CPUs : 0.002051 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:33:07] 0.003221 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:33:19] Energy consumed for RAM : 0.000256 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:33:24] Energy consumed for all GPUs : 0.001017 kWh. Total GPU Power : 20.46848488784803 W
# [codecarbon INFO @ 22:33:24] Energy consumed for all CPUs : 0.002252 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:33:25] 0.003525 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:33:35] Energy consumed for RAM : 0.000271 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:33:39] Energy consumed for all GPUs : 0.001101 kWh. Total GPU Power : 25.48429946278102 W
# [codecarbon INFO @ 22:33:39] Energy consumed for all CPUs : 0.002416 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:33:43] 0.003788 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:33:52] Energy consumed for RAM : 0.000282 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:33:54] Energy consumed for all GPUs : 0.001180 kWh. Total GPU Power : 38.07197010811917 W
# [codecarbon INFO @ 22:33:54] Energy consumed for all CPUs : 0.002519 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:33:54] 0.003980 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:34:08] Energy consumed for RAM : 0.000298 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:34:10] Energy consumed for all GPUs : 0.001248 kWh. Total GPU Power : 22.881359122698626 W
# [codecarbon INFO @ 22:34:10] Energy consumed for all CPUs : 0.002659 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:34:11] 0.004205 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:34:23] Energy consumed for RAM : 0.000318 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:34:25] Energy consumed for all GPUs : 0.001339 kWh. Total GPU Power : 24.33117883020935 W
# [codecarbon INFO @ 22:34:25] Energy consumed for all CPUs : 0.002828 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:34:25] 0.004486 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:34:39] Energy consumed for RAM : 0.000338 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:34:41] Energy consumed for all GPUs : 0.001430 kWh. Total GPU Power : 24.094777806211834 W
# [codecarbon INFO @ 22:34:41] Energy consumed for all CPUs : 0.003004 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:34:42] 0.004772 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:34:55] Energy consumed for RAM : 0.000357 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:34:56] Energy consumed for all GPUs : 0.001505 kWh. Total GPU Power : 23.288908408150146 W
# [codecarbon INFO @ 22:34:56] Energy consumed for all CPUs : 0.003154 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:34:56] 0.005016 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:35:11] Energy consumed for RAM : 0.000380 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:35:13] Energy consumed for all GPUs : 0.001580 kWh. Total GPU Power : 17.961091894280898 W
# [codecarbon INFO @ 22:35:13] Energy consumed for all CPUs : 0.003344 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:35:14] 0.005305 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:35:26] Energy consumed for RAM : 0.000400 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:35:28] Energy consumed for all GPUs : 0.001647 kWh. Total GPU Power : 18.749220099083352 W
# [codecarbon INFO @ 22:35:28] Energy consumed for all CPUs : 0.003507 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:35:29] 0.005555 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:35:42] Energy consumed for RAM : 0.000420 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:35:44] Energy consumed for all GPUs : 0.001732 kWh. Total GPU Power : 22.2111359540992 W
# [codecarbon INFO @ 22:35:44] Energy consumed for all CPUs : 0.003681 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:35:45] 0.005834 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:35:57] Energy consumed for RAM : 0.000441 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:35:59] Energy consumed for all GPUs : 0.001824 kWh. Total GPU Power : 24.018592999732068 W
# [codecarbon INFO @ 22:35:59] Energy consumed for all CPUs : 0.003856 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:35:59] 0.006121 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:36:13] Energy consumed for RAM : 0.000462 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:36:17] Energy consumed for all GPUs : 0.001902 kWh. Total GPU Power : 19.492564238649845 W
# [codecarbon INFO @ 22:36:17] Energy consumed for all CPUs : 0.004046 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:36:17] 0.006411 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:36:29] Energy consumed for RAM : 0.000479 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:36:30] Energy consumed for all GPUs : 0.001962 kWh. Total GPU Power : 20.571301151153104 W
# [codecarbon INFO @ 22:36:30] Energy consumed for all CPUs : 0.004184 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:36:30] 0.006625 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:36:44] Energy consumed for RAM : 0.000500 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:36:47] Energy consumed for all GPUs : 0.002050 kWh. Total GPU Power : 22.266546742802078 W
# [codecarbon INFO @ 22:36:48] Energy consumed for all CPUs : 0.004387 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:36:48] 0.006938 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:36:59] Energy consumed for RAM : 0.000516 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:37:03] Energy consumed for all GPUs : 0.002117 kWh. Total GPU Power : 20.871886650430657 W
# [codecarbon INFO @ 22:37:03] Energy consumed for all CPUs : 0.004542 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:37:03] 0.007176 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:37:15] Energy consumed for RAM : 0.000533 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:37:17] Energy consumed for all GPUs : 0.002185 kWh. Total GPU Power : 24.138777904852876 W
# [codecarbon INFO @ 22:37:17] Energy consumed for all CPUs : 0.004686 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:37:19] 0.007404 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:37:30] Energy consumed for RAM : 0.000549 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:37:34] Energy consumed for all GPUs : 0.002270 kWh. Total GPU Power : 27.05025667701406 W
# [codecarbon INFO @ 22:37:34] Energy consumed for all CPUs : 0.004840 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:37:35] 0.007659 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:37:46] Energy consumed for RAM : 0.000566 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:37:48] Energy consumed for all GPUs : 0.002330 kWh. Total GPU Power : 18.739115661275843 W
# [codecarbon INFO @ 22:37:48] Energy consumed for all CPUs : 0.004989 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:37:48] 0.007885 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:38:01] Energy consumed for RAM : 0.000585 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:38:05] Energy consumed for all GPUs : 0.002402 kWh. Total GPU Power : 18.665359726157657 W
# [codecarbon INFO @ 22:38:05] Energy consumed for all CPUs : 0.005176 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:38:07] 0.008162 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:38:17] Energy consumed for RAM : 0.000602 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:38:18] Energy consumed for all GPUs : 0.002471 kWh. Total GPU Power : 24.498428335493053 W
# [codecarbon INFO @ 22:38:18] Energy consumed for all CPUs : 0.005311 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:38:18] 0.008384 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:38:33] Energy consumed for RAM : 0.000621 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:38:35] Energy consumed for all GPUs : 0.002544 kWh. Total GPU Power : 19.87214507156472 W
# [codecarbon INFO @ 22:38:35] Energy consumed for all CPUs : 0.005480 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:38:36] 0.008645 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:38:48] Energy consumed for RAM : 0.000640 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:38:50] Energy consumed for all GPUs : 0.002614 kWh. Total GPU Power : 19.992993214685143 W
# [codecarbon INFO @ 22:38:50] Energy consumed for all CPUs : 0.005643 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:38:50] 0.008897 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:39:03] Energy consumed for RAM : 0.000661 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:39:05] Energy consumed for all GPUs : 0.002673 kWh. Total GPU Power : 15.245776856235503 W
# [codecarbon INFO @ 22:39:05] Energy consumed for all CPUs : 0.005820 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:39:05] 0.009154 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:39:19] Energy consumed for RAM : 0.000682 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:39:21] Energy consumed for all GPUs : 0.002752 kWh. Total GPU Power : 20.52577637212655 W
# [codecarbon INFO @ 22:39:21] Energy consumed for all CPUs : 0.005994 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:39:22] 0.009429 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:39:34] Energy consumed for RAM : 0.000703 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:39:35] Energy consumed for all GPUs : 0.002819 kWh. Total GPU Power : 18.909668222132858 W
# [codecarbon INFO @ 22:39:36] Energy consumed for all CPUs : 0.006169 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:39:36] 0.009691 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:39:50] Energy consumed for RAM : 0.000725 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:39:52] Energy consumed for all GPUs : 0.002900 kWh. Total GPU Power : 20.351655122521002 W
# [codecarbon INFO @ 22:39:52] Energy consumed for all CPUs : 0.006350 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:39:53] 0.009974 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:40:06] Energy consumed for RAM : 0.000745 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:40:07] Energy consumed for all GPUs : 0.002959 kWh. Total GPU Power : 17.017762861590764 W
# [codecarbon INFO @ 22:40:08] Energy consumed for all CPUs : 0.006530 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:40:09] 0.010235 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:40:21] Energy consumed for RAM : 0.000765 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:40:23] Energy consumed for all GPUs : 0.003041 kWh. Total GPU Power : 22.892915611106933 W
# [codecarbon INFO @ 22:40:23] Energy consumed for all CPUs : 0.006692 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:40:23] 0.010498 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:40:37] Energy consumed for RAM : 0.000788 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:40:39] Energy consumed for all GPUs : 0.003103 kWh. Total GPU Power : 14.965347996416574 W
# [codecarbon INFO @ 22:40:39] Energy consumed for all CPUs : 0.006881 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:40:39] 0.010772 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:40:53] Energy consumed for RAM : 0.000809 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:40:55] Energy consumed for all GPUs : 0.003175 kWh. Total GPU Power : 18.44543958798953 W
# [codecarbon INFO @ 22:40:55] Energy consumed for all CPUs : 0.007059 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:40:55] 0.011043 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:41:09] Energy consumed for RAM : 0.000830 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:41:10] Energy consumed for all GPUs : 0.003241 kWh. Total GPU Power : 18.63827690287934 W
# [codecarbon INFO @ 22:41:10] Energy consumed for all CPUs : 0.007220 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:41:10] 0.011291 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:41:25] Energy consumed for RAM : 0.000853 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:41:28] Energy consumed for all GPUs : 0.003323 kWh. Total GPU Power : 19.50914655956791 W
# [codecarbon INFO @ 22:41:28] Energy consumed for all CPUs : 0.007414 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:41:28] 0.011590 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:41:41] Energy consumed for RAM : 0.000873 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:41:44] Energy consumed for all GPUs : 0.003387 kWh. Total GPU Power : 16.943328330194205 W
# [codecarbon INFO @ 22:41:44] Energy consumed for all CPUs : 0.007589 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:41:44] 0.011850 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:41:57] Energy consumed for RAM : 0.000892 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:41:59] Energy consumed for all GPUs : 0.003453 kWh. Total GPU Power : 18.10019948211856 W
# [codecarbon INFO @ 22:41:59] Energy consumed for all CPUs : 0.007760 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:42:01] 0.012106 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:42:12] Energy consumed for RAM : 0.000910 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:42:13] Energy consumed for all GPUs : 0.003515 kWh. Total GPU Power : 20.14965875615337 W
# [codecarbon INFO @ 22:42:13] Energy consumed for all CPUs : 0.007903 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:42:14] 0.012328 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:42:28] Energy consumed for RAM : 0.000933 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:42:31] Energy consumed for all GPUs : 0.003597 kWh. Total GPU Power : 18.965197991465867 W
# [codecarbon INFO @ 22:42:31] Energy consumed for all CPUs : 0.008107 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:42:33] 0.012637 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:42:43] Energy consumed for RAM : 0.000949 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:42:45] Energy consumed for all GPUs : 0.003659 kWh. Total GPU Power : 19.90570496456164 W
# [codecarbon INFO @ 22:42:45] Energy consumed for all CPUs : 0.008254 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:42:45] 0.012863 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:42:58] Energy consumed for RAM : 0.000969 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:43:00] Energy consumed for all GPUs : 0.003739 kWh. Total GPU Power : 21.452464253137627 W
# [codecarbon INFO @ 22:43:00] Energy consumed for all CPUs : 0.008410 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:43:00] 0.013118 kWh of electricity used since the beginning.
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [codecarbon INFO @ 22:43:16] Energy consumed for RAM : 0.000995 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:43:20] Energy consumed for all GPUs : 0.003814 kWh. Total GPU Power : 14.76774135792349 W
# [codecarbon INFO @ 22:43:20] Energy consumed for all CPUs : 0.008654 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:43:20] 0.013463 kWh of electricity used since the beginning.
# SARIMA Predicted Values:
# 2024-04-01 00:00:00    3.116339
# 2024-04-01 01:00:00    2.797676
# 2024-04-01 02:00:00    2.849620
# 2024-04-01 03:00:00    3.376567
# 2024-04-01 04:00:00    3.863056
# 2024-04-01 05:00:00    4.382018
# 2024-04-01 06:00:00    4.950095
# 2024-04-01 07:00:00    5.394794
# 2024-04-01 08:00:00    5.546068
# 2024-04-01 09:00:00    5.316170
# 2024-04-01 10:00:00    5.041458
# 2024-04-01 11:00:00    4.443765
# 2024-04-01 12:00:00    3.522030
# 2024-04-01 13:00:00    2.731592
# 2024-04-01 14:00:00    1.895598
# 2024-04-01 15:00:00    1.230807
# 2024-04-01 16:00:00    0.861926
# 2024-04-01 17:00:00    0.967708
# 2024-04-01 18:00:00    1.236644
# 2024-04-01 19:00:00    1.682495
# 2024-04-01 20:00:00    2.126467
# 2024-04-01 21:00:00    2.666220
# 2024-04-01 22:00:00    3.289764
# 2024-04-01 23:00:00    3.422823
# Freq: H, Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Calculate and print the RMSE, MAE, and R-squared metrics
rmse = np.sqrt(mean_squared_error(actual_april_1_2024, sarima_forecast_mean))
mae = mean_absolute_error(actual_april_1_2024, sarima_forecast_mean)
r2 = r2_score(actual_april_1_2024, sarima_forecast_mean)

print("RMSE: ", rmse)
print("MAE: ", mae)
print("R-squared: ", r2)
# Out:
# RMSE:  0.4061038283358164
# MAE:  0.33140610212882476
# R-squared:  0.9204132534667897

# %%
# Plotting the SARIMA results with actual verified data for April 1st, 2024
plt.figure(figsize=(14, 7))
plt.plot(actual_april_1_2024.index, actual_april_1_2024, label='Actual Verified Water Level (ft)', color='blue')
plt.plot(sarima_forecast_mean.index, sarima_forecast_mean, label='SARIMA Forecasted Water Level (ft)', color='red', linestyle='--')
plt.fill_between(sarima_forecast_conf_int.index, sarima_forecast_conf_int.iloc[:, 0], sarima_forecast_conf_int.iloc[:, 1], color='red', alpha=0.3)
plt.title('SARIMA Forecast vs Actual Verified Water Levels on April 1, 2024')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Insights from the Plot (SARIMA(1,1,2,24)):
# - This model also follows the trend of the verified data, suggesting the non-seasonal components are well-specified.
# - The wider confidence intervals around noon indicate increased uncertainty during these hours.
# - There's a noticeable deviation from the actual data in the afternoon hours where the model does not capture a dip in water levels seen in the actual data.

# %% [markdown]
# ### Conclusion:
#
# **Case 1: SARIMA(1,1,1,24)**
# - RMSE:  0.719
# - MAE:  0.578
# - R-squared:  0.751
#
# **Case 2: SARIMA(1,1,2,24)**
# - RMSE:  0.406
# - MAE:  0.331
# - R-squared:  0.920
#
# The SARIMA model with parameters (1,1,1,24) provides a forecast that remains consistently below the actual values, while the (1,1,2,24) model shows a slightly better capture of the fluctuations. However, both models underestimate the peaks and overestimate the troughs of the actual verified water levels to some extent. This could be due to inherent limitations of the SARIMA model when dealing with complex seasonal patterns or external influences not captured by the model.
#
# For both models, the forecast's confidence intervals suggest that while the direction of the water level changes is predicted, the magnitude of these changes is uncertain. Refining the model by tuning the seasonal parameters or incorporating exogenous variables (like weather or tidal information) could potentially improve the forecast's accuracy.
#
# In practice, while the SARIMA model provides a reasonable baseline forecast, it's important to incorporate domain-specific knowledge and additional data sources for more accurate predictions. It's also recommended to continuously validate and recalibrate the model with new data.

# %%
# Stop tracking and get emissions data
emissions = tracker.stop()
print(f"Estimated CO2 emissions for the computation: {emissions} kg")
# Out:
# [codecarbon INFO @ 22:43:26] Energy consumed for RAM : 0.001005 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 22:43:26] Energy consumed for all GPUs : 0.003863 kWh. Total GPU Power : 30.4749662919979 W
# [codecarbon INFO @ 22:43:26] Energy consumed for all CPUs : 0.008723 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 22:43:26] 0.013590 kWh of electricity used since the beginning.
# Estimated CO2 emissions for the computation: 0.005016477243669775 kg
