# %%
from codecarbon import EmissionsTracker

# Set up the emissions tracker
tracker = EmissionsTracker()
# Out:
# [codecarbon INFO @ 23:35:06] [setup] RAM Tracking...
# [codecarbon INFO @ 23:35:06] [setup] GPU Tracking...
# [codecarbon INFO @ 23:35:06] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 23:35:06] [setup] CPU Tracking...
# [codecarbon WARNING @ 23:35:06] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 23:35:08] We saw that you have a 12th Gen Intel(R) Core(TM) i7-12700H but we don't know it. Please contact us.
# [codecarbon INFO @ 23:35:08] CPU Model on constant consumption mode: 12th Gen Intel(R) Core(TM) i7-12700H
# [codecarbon INFO @ 23:35:08] >>> Tracker's metadata:
# [codecarbon INFO @ 23:35:08]   Platform system: Windows-10-10.0.22000-SP0
# [codecarbon INFO @ 23:35:08]   Python version: 3.8.5
# [codecarbon INFO @ 23:35:08]   CodeCarbon version: 2.3.5
# [codecarbon INFO @ 23:35:08]   Available RAM : 15.692 GB
# [codecarbon INFO @ 23:35:08]   CPU count: 20
# [codecarbon INFO @ 23:35:08]   CPU model: 12th Gen Intel(R) Core(TM) i7-12700H
# [codecarbon INFO @ 23:35:08]   GPU count: 1
# [codecarbon INFO @ 23:35:08]   GPU model: 1 x NVIDIA GeForce RTX 3070 Ti Laptop GPU

# %%
# Start tracking
tracker.start()

# %%
import pandas as pd

# Load the dataset
file_path = '../data/Water Level - Santa Barbara - v2.csv'
water_data = pd.read_csv(file_path)

# Display the first few rows of the dataframe and its structure
water_data.head(), water_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10944 entries, 0 to 10943
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10944 non-null  object
#  1   Time (GMT)      10944 non-null  object
#  2   Predicted (ft)  10944 non-null  float64
#  3   Verified (ft)   10944 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 342.1+ KB
# (       Date Time (GMT)  Predicted (ft)  Verified (ft)
#  0  1/1/2023       0:00           2.623           3.14
#  1  1/1/2023       1:00           2.964           3.45
#  2  1/1/2023       2:00           3.021           3.74
#  3  1/1/2023       3:00           2.822           3.44
#  4  1/1/2023       4:00           2.450           3.08,
#  None)

# %% [markdown]
# ### Step 1: Load and Inspect the Data
# The dataset contains the following columns:
#
# - Date: The date of the observation.
# - Time (GMT): The hourly time of the observation in GMT.
# - Predicted (ft): NOAA's predicted water level in feet.
# - Verified (ft): The actual verified water level in feet.
#
# The data is formatted with separate columns for date and time, and there are no missing values in the dataset. The next step is to preprocess the data:
#
# ### Step 2: Preprocess the Data
# 1. Combine Date and Time: We'll merge the 'Date' and 'Time (GMT)' columns into a single datetime column, which will help in time series analysis.
# 2. Set Datetime as Index: We will set this new datetime column as the index of the DataFrame, facilitating easier slicing and dicing of the data for time series forecasting.
# 3. Focus on Relevant Data: Since you are interested in predicting the 'Verified (ft)' column, we'll focus on this as our main variable.

# %%
import matplotlib.pyplot as plt

# Combine Date and Time columns into a single datetime column
water_data['Datetime'] = pd.to_datetime(water_data['Date'] + ' ' + water_data['Time (GMT)'])
water_data.set_index('Datetime', inplace=True)

# Dropping the original Date and Time columns as they are no longer needed
water_data.drop(columns=['Date', 'Time (GMT)'], inplace=True)

# %%
# Focus on the 'Verified (ft)' column
water_level_data = water_data[['Verified (ft)']]

# Show the first few rows of the new DataFrame and the overall index type to confirm changes
water_level_data.head(), water_level_data.index
# Out:
# (                     Verified (ft)
#  Datetime
#  2023-01-01 00:00:00           3.14
#  2023-01-01 01:00:00           3.45
#  2023-01-01 02:00:00           3.74
#  2023-01-01 03:00:00           3.44
#  2023-01-01 04:00:00           3.08,
#  DatetimeIndex(['2023-01-01 00:00:00', '2023-01-01 01:00:00',
#                 '2023-01-01 02:00:00', '2023-01-01 03:00:00',
#                 '2023-01-01 04:00:00', '2023-01-01 05:00:00',
#                 '2023-01-01 06:00:00', '2023-01-01 07:00:00',
#                 '2023-01-01 08:00:00', '2023-01-01 09:00:00',
#                 ...
#                 '2024-03-31 14:00:00', '2024-03-31 15:00:00',
#                 '2024-03-31 16:00:00', '2024-03-31 17:00:00',
#                 '2024-03-31 18:00:00', '2024-03-31 19:00:00',
#                 '2024-03-31 20:00:00', '2024-03-31 21:00:00',
#                 '2024-03-31 22:00:00', '2024-03-31 23:00:00'],
#                dtype='datetime64[ns]', name='Datetime', length=10944, freq=None))

# %% [markdown]
# The preprocessing steps are now complete:
#
# - The 'Date' and 'Time (GMT)' columns have been merged into a single 'DateTime' column.
# - This 'DateTime' column is now set as the index of the DataFrame, which is structured for time series analysis focusing on the 'Verified (ft)' water level measurements.
#
# ### Step 3: Visualize the Data
# To better understand any underlying trends, seasonality, or other patterns in the water level data, let's visualize it. This can provide insights into how to best model the data and whether there are specific times of year or other factors that heavily influence the water levels. We'll create a time series plot of the 'Verified (ft)' water levels.
#
# - Seasonal Decomposition: We will perform a seasonal decomposition to visually inspect the trends, seasonality, and residuals.

# %%
import matplotlib.pyplot as plt

# Plotting the Verified Water Levels
plt.figure(figsize=(14, 7))
plt.plot(water_data.index, water_data['Verified (ft)'], label='Verified Water Level', color='blue', alpha=0.6)
plt.plot(water_data.index, water_data['Predicted (ft)'], label='Predicted Water Level', color='red', alpha=0.6)
plt.title('Verified vs Predicted Water Levels over Time')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.show()

# %% [markdown]
# The plot above displays the verified water levels over time from January 2023 to March 2024. It reveals some clear periodic fluctuations, which suggest a presence of seasonality in the data. Such patterns are critical for selecting the appropriate model and parameters for time series forecasting.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Seasonal decomposition of the original 'Verified (ft)' data
decomposition = seasonal_decompose(water_data['Verified (ft)'], model='additive', period=24)  # Assuming daily seasonality

# Plotting the seasonal decomposition components
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(15, 12))
decomposition.observed.plot(ax=ax1, title='Observed')
decomposition.trend.plot(ax=ax2, title='Trend')
decomposition.seasonal.plot(ax=ax3, title='Seasonal')
decomposition.resid.plot(ax=ax4, title='Residual')
plt.tight_layout()
plt.show()

# %% [markdown]
# The seasonal decomposition plots provide the following insights into the water level data:
#
# 1. Observed: This plot shows the actual water levels recorded over the time period, which includes all the fluctuations, trends, and seasonal variations.
# 2. Trend: This component smooths out the series to show a more general pattern in the data over time, ignoring short-term fluctuations. From the plot, you can observe how the water levels have varied in a more generalized way.
# 3. Seasonal: This plot reveals the daily cycle in the water levels. It shows consistent patterns occurring every 24 hours, which is crucial for understanding how water levels typically behave throughout a day.
# 4. Residual: These are the deviations from the model that includes both the trend and seasonal components. Ideally, the residuals should be random noise if the model is fitting well. Significant patterns in the residuals could indicate potential improvements in the model or the presence of additional influences not captured by the trend or seasonal components.

# %% [markdown]
# ### Step 4: Stationarity Check
# For ARIMA modeling, the time series data should be stationary. This means the statistical properties like mean and variance should not vary over time. Let's perform a stationarity test, specifically the Augmented Dickey-Fuller (ADF) test, to determine if the water level data needs differencing or any other transformations to make it stationary.

# %%
from statsmodels.tsa.stattools import adfuller

# Performing Augmented Dickey-Fuller test on the 'Verified (ft)' column
adf_result = adfuller(water_data['Verified (ft)'])

# Displaying ADF Test Results
adf_output = pd.Series(adf_result[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key, value in adf_result[4].items():
    adf_output[f'Critical Value ({key})'] = value

adf_output
# Out:
# Test Statistic                    -2.816309
# p-value                            0.055982
# #Lags Used                        39.000000
# Number of Observations Used    10904.000000
# Critical Value (1%)               -3.430950
# Critical Value (5%)               -2.861805
# Critical Value (10%)              -2.566911
# dtype: float64

# %% [markdown]
# The results from the Augmented Dickey-Fuller (ADF) test are as follows:
#
# - ADF Test Statistic: `−2.816`
# - p-value: `0.056`
#
# The test statistic is not less than the critical values at conventional significance levels (1%, 5%, 10%). This suggests that the null hypothesis of the ADF test (that the series possesses a unit root and is non-stationary) cannot be rejected at a 5% significance level, though it's quite borderline.
#
# ### Step 5: Differencing the Series
# Given that the series is nearly stationary but not conclusively so, we will first difference the series once and then check for stationarity again to confirm if it's adequate for ARIMA modeling.
#
# Let's proceed by differencing the series and then testing for stationarity again.

# %%
# Applying first order differencing to the 'Verified (ft)' column
water_data['Verified_diff'] = water_data['Verified (ft)'].diff()

# Dropping NaN values that result from differencing
water_data_diff = water_data.dropna()

# Re-performing the Augmented Dickey-Fuller test on the differenced data
adf_result_diff = adfuller(water_data_diff['Verified_diff'])

# Displaying ADF Test Results for differenced data
adf_output_diff = pd.Series(adf_result_diff[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key, value in adf_result_diff[4].items():
    adf_output_diff[f'Critical Value ({key})'] = value

adf_output_diff
# Out:
# Test Statistic                   -33.430794
# p-value                            0.000000
# #Lags Used                        39.000000
# Number of Observations Used    10903.000000
# Critical Value (1%)               -3.430950
# Critical Value (5%)               -2.861805
# Critical Value (10%)              -2.566911
# dtype: float64

# %% [markdown]
# The results from the Augmented Dickey-Fuller test on the differenced series are:
#
# - ADF Test Statistic: `−33.431`
# - p-value: `0.0`
#
# The test statistic is significantly less than the critical values for all common significance levels (1%, 5%, 10%). This indicates that the differenced series is stationary. Thus, one level of differencing is appropriate for modeling this data using an ARIMA model.
#
# ### Step 6: Model Selection and Fitting
# We will next use the AutoCorrelation Function (ACF) and Partial AutoCorrelation Function (PACF) plots to determine the order of the ARIMA model. These plots help identify the parameters (p, d, q):
#
# - p (AR term) can be estimated from the PACF.
# - d (differencing order) is 1, as we determined from the differencing step.
# - q (MA term) can be estimated from the ACF.
#
# Let's generate the ACF and PACF plots for the differenced data to help us select the best parameters for the ARIMA model. ​

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plotting the ACF and PACF for the differenced data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))
plot_acf(water_data_diff['Verified_diff'], lags=50, ax=ax1, title='Autocorrelation Function')
plot_pacf(water_data_diff['Verified_diff'], lags=50, ax=ax2, title='Partial Autocorrelation Function')
plt.tight_layout()
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# Differencing the series once
water_level_diff = water_data['Verified (ft)'].diff().dropna()

# Perform the Augmented Dickey-Fuller test on the differenced data
adf_result_diff = adfuller(water_level_diff)

# Extract and display the ADF test results for the differenced data
adf_test_statistic_diff = adf_result_diff[0]
p_value_diff = adf_result_diff[1]
critical_values_diff = adf_result_diff[4]

adf_test_statistic_diff, p_value_diff, critical_values_diff
# Out:
# (-33.430794222066794,
#  0.0,
#  {'1%': -3.430949911973261,
#   '5%': -2.8618051278244807,
#   '10%': -2.5669111224099344})

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plotting ACF and PACF
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Plot the ACF
plot_acf(water_level_diff, lags=50, ax=ax1)
ax1.set_title('Autocorrelation Function')

# Plot the PACF
plot_pacf(water_level_diff, lags=50, ax=ax2)
ax2.set_title('Partial Autocorrelation Function')

plt.tight_layout()
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ### Parameter Estimation from ACF and PACF Plots:
# - ACF Plot: Shows significant lags at the initial points and then it tapers off, suggesting potential MA components.
# - PACF Plot: Sharp cut-off after the first few lags, indicating potential AR components.
# ### Proposed ARIMA Model:
# - p (AR terms): The PACF plot shows significance at lag 1 primarily. This suggests setting `p=1`.
# - d (Differencing order): We already determined `d=1` from our stationarity analysis.
# - q (MA terms): The ACF plot shows a few significant lags, especially at lag 1 and somewhat at lag 2, suggesting `q=1` or `q=2`.
#
# Let's fit an ARIMA model with these parameters, `ARIMA(1,1,1)` and `ARIMA(1,1,2)`, to the water level data. We'll then forecast the water level for each hour on 04/01/2024. Let's proceed to fit the model and perform the forecast.

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit the ARIMA model
model = ARIMA(water_level_data, order=(1, 1, 1))
model_fit = model.fit()

# Forecast water levels
forecast_date = '2024-04-01'
forecast_hours = 24  # Number of hours in the day to forecast
forecast_result = model_fit.get_forecast(steps=forecast_hours)

# Extract forecast mean and confidence intervals
forecast_mean = forecast_result.predicted_mean
forecast_conf_int = forecast_result.conf_int()

forecast_mean, forecast_conf_int
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# (2024-04-01 00:00:00    2.884456
#  2024-04-01 01:00:00    2.911267
#  2024-04-01 02:00:00    2.932129
#  2024-04-01 03:00:00    2.948362
#  2024-04-01 04:00:00    2.960994
#  2024-04-01 05:00:00    2.970822
#  2024-04-01 06:00:00    2.978470
#  2024-04-01 07:00:00    2.984421
#  2024-04-01 08:00:00    2.989052
#  2024-04-01 09:00:00    2.992655
#  2024-04-01 10:00:00    2.995459
#  2024-04-01 11:00:00    2.997641
#  2024-04-01 12:00:00    2.999338
#  2024-04-01 13:00:00    3.000659
#  2024-04-01 14:00:00    3.001687
#  2024-04-01 15:00:00    3.002487
#  2024-04-01 16:00:00    3.003109
#  2024-04-01 17:00:00    3.003593
#  2024-04-01 18:00:00    3.003970
#  2024-04-01 19:00:00    3.004263
#  2024-04-01 20:00:00    3.004491
#  2024-04-01 21:00:00    3.004669
#  2024-04-01 22:00:00    3.004807
#  2024-04-01 23:00:00    3.004914
#  Freq: H, Name: predicted_mean, dtype: float64,
#                       lower Verified (ft)  upper Verified (ft)
#  2024-04-01 00:00:00             2.160175             3.608737
#  2024-04-01 01:00:00             1.291209             4.531324
#  2024-04-01 02:00:00             0.348059             5.516200
#  2024-04-01 03:00:00            -0.613933             6.510658
#  2024-04-01 04:00:00            -1.566020             7.488008
#  2024-04-01 05:00:00            -2.492970             8.434615
#  2024-04-01 06:00:00            -3.387069             9.344009
#  2024-04-01 07:00:00            -4.244962            10.213805
#  2024-04-01 08:00:00            -5.065861            11.043965
#  2024-04-01 09:00:00            -5.850467            11.835777
#  2024-04-01 10:00:00            -6.600322            12.591240
#  2024-04-01 11:00:00            -7.317404            13.312686
#  2024-04-01 12:00:00            -8.003878            14.002554
#  2024-04-01 13:00:00            -8.661940            14.663258
#  2024-04-01 14:00:00            -9.293731            15.297105
#  2024-04-01 15:00:00            -9.901282            15.906255
#  2024-04-01 16:00:00           -10.486488            16.492705
#  2024-04-01 17:00:00           -11.051097            17.058283
#  2024-04-01 18:00:00           -11.596711            17.604651
#  2024-04-01 19:00:00           -12.124790            18.133317
#  2024-04-01 20:00:00           -12.636658            18.645640
#  2024-04-01 21:00:00           -13.133514            19.142852
#  2024-04-01 22:00:00           -13.616446            19.626060
#  2024-04-01 23:00:00           -14.086437            20.096266)

# %%
# Extracting data for March 2024 for plotting context
march_2024_data = water_level_data['2024-03-01':'2024-03-31']

# Concatenate the March 2024 data with the forecast data for April 1st, 2024
combined_data = pd.concat([march_2024_data, forecast_mean])

# %%
# Plotting the results without confidence intervals due to previous error
plt.figure(figsize=(14, 7))
plt.plot(march_2024_data.index, march_2024_data['Verified (ft)'], label='Actual Verified Water Level (ft)', color='blue')
plt.plot(forecast_mean.index, forecast_mean, label='Forecasted Water Level (ft)', color='red', linestyle='--')
plt.title('Water Level Forecast vs Actual Data')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The ARIMA(1,1,1) model has provided the following forecast for the water levels on April 1st, 2024:
#
# - Predicted Mean Water Levels (ft): Values start from approximately 2.88 ft at midnight and slightly increase throughout the day, reaching about 3.00 ft by 11 PM.
# - Confidence Intervals: The forecast shows increasing uncertainty as time progresses, starting with a fairly tight confidence interval at midnight (from about 2.16 ft to 3.61 ft) and widening significantly towards the end of the day (from about -14.09 ft to 20.10 ft). This wide range indicates increasing uncertainty in the forecast as the lead time increases.

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit the ARIMA model
model = ARIMA(water_level_data, order=(1, 1, 2))
model_fit = model.fit()

# Forecast water levels
forecast_date = '2024-04-01'
forecast_hours = 24  # Number of hours in the day to forecast
forecast_result = model_fit.get_forecast(steps=forecast_hours)

# Extract forecast mean and confidence intervals
forecast_mean = forecast_result.predicted_mean
forecast_conf_int = forecast_result.conf_int()

forecast_mean, forecast_conf_int
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# (2024-04-01 00:00:00    2.832876
#  2024-04-01 01:00:00    2.779815
#  2024-04-01 02:00:00    2.740385
#  2024-04-01 03:00:00    2.711084
#  2024-04-01 04:00:00    2.689310
#  2024-04-01 05:00:00    2.673129
#  2024-04-01 06:00:00    2.661104
#  2024-04-01 07:00:00    2.652169
#  2024-04-01 08:00:00    2.645529
#  2024-04-01 09:00:00    2.640595
#  2024-04-01 10:00:00    2.636928
#  2024-04-01 11:00:00    2.634203
#  2024-04-01 12:00:00    2.632178
#  2024-04-01 13:00:00    2.630673
#  2024-04-01 14:00:00    2.629555
#  2024-04-01 15:00:00    2.628724
#  2024-04-01 16:00:00    2.628107
#  2024-04-01 17:00:00    2.627648
#  2024-04-01 18:00:00    2.627307
#  2024-04-01 19:00:00    2.627053
#  2024-04-01 20:00:00    2.626865
#  2024-04-01 21:00:00    2.626725
#  2024-04-01 22:00:00    2.626621
#  2024-04-01 23:00:00    2.626544
#  Freq: H, Name: predicted_mean, dtype: float64,
#                       lower Verified (ft)  upper Verified (ft)
#  2024-04-01 00:00:00             2.195708             3.470044
#  2024-04-01 01:00:00             1.426159             4.133471
#  2024-04-01 02:00:00             0.377493             5.103278
#  2024-04-01 03:00:00            -0.720451             6.142618
#  2024-04-01 04:00:00            -1.802463             7.181082
#  2024-04-01 05:00:00            -2.843703             8.189961
#  2024-04-01 06:00:00            -3.834772             9.156981
#  2024-04-01 07:00:00            -4.773436            10.077774
#  2024-04-01 08:00:00            -5.660975            10.952033
#  2024-04-01 09:00:00            -6.500343            11.781533
#  2024-04-01 10:00:00            -7.295197            12.569053
#  2024-04-01 11:00:00            -8.049369            13.317775
#  2024-04-01 12:00:00            -8.766588            14.030944
#  2024-04-01 13:00:00            -9.450346            14.711692
#  2024-04-01 14:00:00           -10.103832            15.362942
#  2024-04-01 15:00:00           -10.729921            15.987370
#  2024-04-01 16:00:00           -11.331182            16.587395
#  2024-04-01 17:00:00           -11.909894            17.165189
#  2024-04-01 18:00:00           -12.468079            17.722693
#  2024-04-01 19:00:00           -13.007525            18.261632
#  2024-04-01 20:00:00           -13.529815            18.783545
#  2024-04-01 21:00:00           -14.036349            19.289799
#  2024-04-01 22:00:00           -14.528370            19.781612
#  2024-04-01 23:00:00           -15.006984            20.260071)

# %%
# Extracting data for March 2024 for plotting context
march_2024_data = water_level_data['2024-03-01':'2024-03-31']

# Concatenate the March 2024 data with the forecast data for April 1st, 2024
combined_data = pd.concat([march_2024_data, forecast_mean])

# %%
# Plotting the results without confidence intervals due to previous error
plt.figure(figsize=(14, 7))
plt.plot(march_2024_data.index, march_2024_data['Verified (ft)'], label='Actual Verified Water Level (ft)', color='blue')
plt.plot(forecast_mean.index, forecast_mean, label='Forecasted Water Level (ft)', color='red', linestyle='--')
plt.title('Water Level Forecast vs Actual Data')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The ARIMA(1,1,2) model has provided the following forecast for the water levels on April 1st, 2024:
#
# - Predicted Mean Water Levels (ft): Values start from approximately 2.83 ft at midnight and slightly decrease throughout the day, reaching about 2.63 ft by 11 PM.
# - Confidence Intervals: The forecast shows increasing uncertainty as time progresses, starting with a fairly tight confidence interval at midnight (from about 2.20 ft to 3.47 ft) and widening significantly towards the end of the day (from about -15.00 ft to 20.26 ft). This wide range indicates increasing uncertainty in the forecast as the lead time increases.

# %% [markdown]
# The seasonal decomposition mentioned before provided a few insights that could be useful for refining the ARIMA prediction:
#
# 1. Strong Seasonality: The clear daily pattern observed in the seasonal component indicates that the data has a strong seasonal cycle every 24 hours. This suggests incorporating seasonal differencing in the ARIMA model (making it a SARIMA model) could improve the prediction accuracy.
# 2. Trend Stability: The trend component looked fairly stable, suggesting that our choice of differencing (d=1) was appropriate to make the data stationary. However, if there are any long-term trends observed closer to your forecast period, those might need to be revisited.
# 3. Residual Analysis: Ideally, the residuals should be noise-like. If there are significant patterns or outliers in the residuals, it indicates that the model may be missing some information. Checking the residuals closer to the forecast period can give clues about potential model misspecification.

# %%
# Load the future data provided
future_data_path = '../data/future data - Santa Barbara.csv'
future_data = pd.read_csv(future_data_path)

# Display the first few rows of the future data and its info
future_data.head(), future_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            24 non-null     object
#  1   Time (GMT)      24 non-null     object
#  2   Predicted (ft)  24 non-null     float64
#  3   Verified (ft)   24 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 896.0+ bytes
# (       Date Time (GMT)  Predicted (ft)  Verified (ft)
#  0  4/1/2024       0:00           2.581           2.83
#  1  4/1/2024       1:00           2.674           3.01
#  2  4/1/2024       2:00           2.780           3.05
#  3  4/1/2024       3:00           2.943           3.29
#  4  4/1/2024       4:00           3.196           3.41,
#  None)

# %% [markdown]
# The future data for April 1st, 2024, has been successfully loaded and includes the following columns:
#
# - Date: Specifies the date for each entry.
# - Time (GMT): Specifies the hourly time.
# - Predicted (ft): NOAA's prediction for the water level at each hour.
# - Verified (ft): The actual verified water level at each hour.
#
# The data includes both predicted and verified water levels for every hour of April 1st, 2024. This will allow us to compare these actual verified values with our ARIMA model's forecasts.
#
# Let's proceed by comparing our ARIMA forecasts with the actual verified water levels to evaluate the model's accuracy and see if any adjustments based on the future data are necessary. I will plot both the forecasted and actual verified water levels for visual comparison

# %%
# Preprocess future data: Combine Date and Time into a datetime index
future_data['DateTime'] = pd.to_datetime(future_data['Date'] + ' ' + future_data['Time (GMT)'])
future_data.set_index('DateTime', inplace=True)

# Extract the verified water levels for April 1st, 2024 from the future data
actual_april_1_2024 = future_data['Verified (ft)']

# Plotting the forecasted results with actual verified data for April 1st, 2024
plt.figure(figsize=(14, 7))
plt.plot(forecast_mean.index, forecast_mean, label='ARIMA Forecasted Water Level (ft)', color='red', linestyle='--')
plt.plot(actual_april_1_2024.index, actual_april_1_2024, label='Actual Verified Water Level (ft)', color='blue')
plt.title('ARIMA Forecast vs Actual Verified Water Levels on April 1, 2024')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The plot above displays both the ARIMA model's forecasted water levels and the actual verified water levels for April 1st, 2024.
#
# ### Observations from the Comparison:
# - General Trend: The ARIMA forecast appears to capture the general rising trend of the water levels throughout the day, which is a good indication of the model's effectiveness.
# - Magnitude of Predictions: The forecasted levels seem to consistently underestimate the actual verified water levels, suggesting that the model might benefit from adjustments. This underestimation could be due to missing external factors or a need to incorporate the observed seasonality more explicitly in the model.
# ### Potential Adjustments:
# 1. Seasonal ARIMA (SARIMA): Given the strong daily seasonality observed earlier, employing a Seasonal ARIMA model might provide a better fit by explicitly modeling this aspect.
# 2. Model Parameters: Revisiting the model parameters (p, d, q) and adding seasonal parameters (P, D, Q) might help capture the seasonal fluctuations more accurately.
# 3. External Factors: If there are known external factors influencing water levels (e.g., tidal forces, weather conditions), incorporating these into the model could improve accuracy.

# %% [markdown]
# Using a Seasonal ARIMA (SARIMA) model is an effective way to account for and leverage the periodic fluctuations in data that exhibits strong seasonal patterns, such as the daily seasonality observed in your water level data. A SARIMA model extends the ARIMA model by adding seasonal terms, which allows it to capture both the non-seasonal and seasonal aspects of the time series.
#
# ### Components of a SARIMA Model
# A SARIMA model is typically denoted as SARIMA(p, d, q)(P, D, Q)[m], where:
#
# - `p,d,q` are the non-seasonal parameters for autoregression, differencing, and moving average components, respectively.
#
# - `P,D,Q` are the seasonal components of the model, mirroring the non-seasonal components but applied on the seasonality cycle.
#
# - `m` is the length of the seasonal cycle. In this case, `m=24` hours based on daily seasonality.
#
# ### Steps to Implement SARIMA:
# 1. Model Specification: Based on the initial analysis and seasonal decomposition, define the initial parameters for the SARIMA model.
# 2. Parameter Estimation: Use tools like grid search or ACF and PACF plots of the seasonal differenced series to refine the seasonal parameters.
# 3. Model Fitting: Fit the SARIMA model to your historical data.
# 4. Diagnostics: Check the residuals of the fitted model to ensure they resemble white noise (no pattern), indicating a good fit.
# 5. Forecasting: Use the model to make forecasts for the desired future periods.
# 6. Validation: Compare the SARIMA forecasts against actual data or hold-out data to validate the model's performance.
#
# Let's begin by specifying a SARIMA model based on the earlier ARIMA(1,1,1) and incorporating a seasonal component. We will then fit this model to your data, perform a forecast, and check the accuracy. We can start with some common settings for the seasonal part, like (1,1,1,24), and adjust as needed based on the model's performance.

# %% [markdown]
# ##### Case 1: SARIMA(1,1,1,24)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Fit the SARIMA model
sarima_model = SARIMAX(water_level_data['Verified (ft)'],
                       order=(1, 1, 1),
                       seasonal_order=(1, 1, 1, 24),
                       enforce_stationarity=False,
                       enforce_invertibility=False)
sarima_model_fit = sarima_model.fit(disp=False)

# Forecast using the SARIMA model for April 1, 2024
sarima_forecast_result = sarima_model_fit.get_forecast(steps=24)

# Extract forecast mean and confidence intervals
sarima_forecast_mean = sarima_forecast_result.predicted_mean
sarima_forecast_conf_int = sarima_forecast_result.conf_int()

# Print the SARIMA predicted values
print("SARIMA Predicted Values:")
print(sarima_forecast_mean)
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# [codecarbon INFO @ 23:35:26] Energy consumed for RAM : 0.000025 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:35:27] Energy consumed for all GPUs : 0.000073 kWh. Total GPU Power : 17.085795171092645 W
# [codecarbon INFO @ 23:35:27] Energy consumed for all CPUs : 0.000184 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:35:27] 0.000281 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:35:42] Energy consumed for RAM : 0.000050 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:35:43] Energy consumed for all GPUs : 0.000143 kWh. Total GPU Power : 16.51101454815332 W
# [codecarbon INFO @ 23:35:45] Energy consumed for all CPUs : 0.000390 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:35:45] 0.000583 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:35:57] Energy consumed for RAM : 0.000070 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:35:59] Energy consumed for all GPUs : 0.000211 kWh. Total GPU Power : 18.68494361046962 W
# [codecarbon INFO @ 23:35:59] Energy consumed for all CPUs : 0.000559 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:36:00] 0.000840 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:36:13] Energy consumed for RAM : 0.000089 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:36:15] Energy consumed for all GPUs : 0.000281 kWh. Total GPU Power : 19.80071035216712 W
# [codecarbon INFO @ 23:36:15] Energy consumed for all CPUs : 0.000722 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:36:16] 0.001092 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:36:28] Energy consumed for RAM : 0.000108 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:36:31] Energy consumed for all GPUs : 0.000352 kWh. Total GPU Power : 20.130268417948596 W
# [codecarbon INFO @ 23:36:32] Energy consumed for all CPUs : 0.000896 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:36:33] 0.001355 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:36:44] Energy consumed for RAM : 0.000125 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:36:47] Energy consumed for all GPUs : 0.000425 kWh. Total GPU Power : 20.741316793282387 W
# [codecarbon INFO @ 23:36:48] Energy consumed for all CPUs : 0.001058 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:36:49] 0.001608 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:37:00] Energy consumed for RAM : 0.000142 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:37:03] Energy consumed for all GPUs : 0.000494 kWh. Total GPU Power : 19.694041405298595 W
# [codecarbon INFO @ 23:37:03] Energy consumed for all CPUs : 0.001219 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:37:04] 0.001854 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:37:15] Energy consumed for RAM : 0.000159 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:37:18] Energy consumed for all GPUs : 0.000560 kWh. Total GPU Power : 18.02784720568129 W
# [codecarbon INFO @ 23:37:20] Energy consumed for all CPUs : 0.001401 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:37:20] 0.002120 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:37:30] Energy consumed for RAM : 0.000175 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:37:33] Energy consumed for all GPUs : 0.000622 kWh. Total GPU Power : 21.24770079012391 W
# [codecarbon INFO @ 23:37:33] Energy consumed for all CPUs : 0.001540 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:37:33] 0.002337 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:37:49] Energy consumed for RAM : 0.000202 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:37:57] Energy consumed for all GPUs : 0.000727 kWh. Total GPU Power : 18.4468249083368 W
# [codecarbon INFO @ 23:37:57] Energy consumed for all CPUs : 0.001830 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:37:57] 0.002758 kWh of electricity used since the beginning.
# SARIMA Predicted Values:
# 2024-04-01 00:00:00    2.770929
# 2024-04-01 01:00:00    2.747512
# 2024-04-01 02:00:00    2.926893
# 2024-04-01 03:00:00    3.338754
# 2024-04-01 04:00:00    3.703026
# 2024-04-01 05:00:00    4.167481
# 2024-04-01 06:00:00    4.652255
# 2024-04-01 07:00:00    4.709119
# 2024-04-01 08:00:00    4.785535
# 2024-04-01 09:00:00    4.562626
# 2024-04-01 10:00:00    4.241787
# 2024-04-01 11:00:00    3.475886
# 2024-04-01 12:00:00    2.903414
# 2024-04-01 13:00:00    2.426481
# 2024-04-01 14:00:00    1.958228
# 2024-04-01 15:00:00    1.571438
# 2024-04-01 16:00:00    1.440474
# 2024-04-01 17:00:00    1.514670
# 2024-04-01 18:00:00    1.585429
# 2024-04-01 19:00:00    1.926689
# 2024-04-01 20:00:00    2.225579
# 2024-04-01 21:00:00    2.501426
# 2024-04-01 22:00:00    2.660441
# 2024-04-01 23:00:00    2.692097
# Freq: H, Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Calculate and print the RMSE, MAE, and R-squared metrics
rmse = np.sqrt(mean_squared_error(actual_april_1_2024, sarima_forecast_mean))
mae = mean_absolute_error(actual_april_1_2024, sarima_forecast_mean)
r2 = r2_score(actual_april_1_2024, sarima_forecast_mean)

print("RMSE: ", rmse)
print("MAE: ", mae)
print("R-squared: ", r2)
# Out:
# RMSE:  0.7424757817263321
# MAE:  0.5774827587697974
# R-squared:  0.7535460141925683

# %%
# Plotting the SARIMA results with actual verified data for April 1st, 2024
plt.figure(figsize=(14, 7))
plt.plot(actual_april_1_2024.index, actual_april_1_2024, label='Actual Verified Water Level (ft)', color='blue')
plt.plot(sarima_forecast_mean.index, sarima_forecast_mean, label='SARIMA Forecasted Water Level (ft)', color='red', linestyle='--')
plt.fill_between(sarima_forecast_conf_int.index, sarima_forecast_conf_int.iloc[:, 0], sarima_forecast_conf_int.iloc[:, 1], color='red', alpha=0.3)
plt.title('SARIMA Forecast vs Actual Verified Water Levels on April 1, 2024')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [codecarbon INFO @ 23:39:04] Energy consumed for RAM : 0.000311 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:39:04] Energy consumed for all GPUs : 0.001080 kWh. Total GPU Power : 18.419706502347356 W
# [codecarbon INFO @ 23:39:04] Energy consumed for all CPUs : 0.002619 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:39:04] 0.004009 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:39:19] Energy consumed for RAM : 0.000335 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:39:19] Energy consumed for all GPUs : 0.001151 kWh. Total GPU Power : 17.05298293842318 W
# [codecarbon INFO @ 23:39:19] Energy consumed for all CPUs : 0.002796 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:39:19] 0.004282 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:39:34] Energy consumed for RAM : 0.000360 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:39:34] Energy consumed for all GPUs : 0.001243 kWh. Total GPU Power : 22.13400784544116 W
# [codecarbon INFO @ 23:39:34] Energy consumed for all CPUs : 0.002973 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:39:34] 0.004576 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:39:49] Energy consumed for RAM : 0.000384 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:39:49] Energy consumed for all GPUs : 0.001311 kWh. Total GPU Power : 16.325090026749844 W
# [codecarbon INFO @ 23:39:49] Energy consumed for all CPUs : 0.003150 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:39:49] 0.004846 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:40:04] Energy consumed for RAM : 0.000409 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:40:04] Energy consumed for all GPUs : 0.001378 kWh. Total GPU Power : 16.035933837961036 W
# [codecarbon INFO @ 23:40:04] Energy consumed for all CPUs : 0.003327 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:40:04] 0.005114 kWh of electricity used since the beginning.

# %% [markdown]
# ### Insights from the Plot (SARIMA(1,1,1,24)):
# - The model captures the overall trend in the water level data reasonably well.
# - The confidence intervals are wide, indicating a significant amount of uncertainty in the forecasts.
# - The forecasted values start off closely following the actual verified water levels but begin to diverge as time progresses.

# %% [markdown]
# ##### Case 2: SARIMA(1,1,2,24)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Fit the SARIMA model
sarima_model = SARIMAX(water_level_data['Verified (ft)'],
                       order=(1, 1, 2),
                       seasonal_order=(1, 1, 2, 24),
                       enforce_stationarity=False,
                       enforce_invertibility=False)
sarima_model_fit = sarima_model.fit(disp=False)

# Forecast using the SARIMA model for April 1, 2024
sarima_forecast_result = sarima_model_fit.get_forecast(steps=24)

# Extract forecast mean and confidence intervals
sarima_forecast_mean = sarima_forecast_result.predicted_mean
sarima_forecast_conf_int = sarima_forecast_result.conf_int()

# Print the SARIMA predicted values
print("SARIMA Predicted Values:")
print(sarima_forecast_mean)
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# D:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# [codecarbon INFO @ 23:40:19] Energy consumed for RAM : 0.000434 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:40:20] Energy consumed for all GPUs : 0.001447 kWh. Total GPU Power : 16.146235287268784 W
# [codecarbon INFO @ 23:40:20] Energy consumed for all CPUs : 0.003521 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:40:21] 0.005402 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:40:35] Energy consumed for RAM : 0.000454 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:40:36] Energy consumed for all GPUs : 0.001519 kWh. Total GPU Power : 21.619015221701055 W
# [codecarbon INFO @ 23:40:36] Energy consumed for all CPUs : 0.003676 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:40:36] 0.005649 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:40:50] Energy consumed for RAM : 0.000475 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:40:53] Energy consumed for all GPUs : 0.001600 kWh. Total GPU Power : 19.423094253699144 W
# [codecarbon INFO @ 23:40:53] Energy consumed for all CPUs : 0.003871 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:40:53] 0.005946 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:41:05] Energy consumed for RAM : 0.000491 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:41:08] Energy consumed for all GPUs : 0.001669 kWh. Total GPU Power : 23.84120448633301 W
# [codecarbon INFO @ 23:41:08] Energy consumed for all CPUs : 0.004009 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:41:09] 0.006169 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:41:21] Energy consumed for RAM : 0.000510 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:41:26] Energy consumed for all GPUs : 0.001747 kWh. Total GPU Power : 20.36282766199203 W
# [codecarbon INFO @ 23:41:26] Energy consumed for all CPUs : 0.004196 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:41:26] 0.006452 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:41:37] Energy consumed for RAM : 0.000525 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:41:40] Energy consumed for all GPUs : 0.001825 kWh. Total GPU Power : 26.259832913858645 W
# [codecarbon INFO @ 23:41:40] Energy consumed for all CPUs : 0.004340 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:41:40] 0.006690 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:41:53] Energy consumed for RAM : 0.000546 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:41:56] Energy consumed for all GPUs : 0.001933 kWh. Total GPU Power : 28.679652712230812 W
# [codecarbon INFO @ 23:41:57] Energy consumed for all CPUs : 0.004528 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:41:57] 0.007006 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:42:09] Energy consumed for RAM : 0.000564 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:42:11] Energy consumed for all GPUs : 0.002022 kWh. Total GPU Power : 26.094907273939224 W
# [codecarbon INFO @ 23:42:11] Energy consumed for all CPUs : 0.004683 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:42:11] 0.007269 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:42:25] Energy consumed for RAM : 0.000584 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:42:27] Energy consumed for all GPUs : 0.002098 kWh. Total GPU Power : 20.327468698503203 W
# [codecarbon INFO @ 23:42:27] Energy consumed for all CPUs : 0.004855 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:42:27] 0.007537 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:42:40] Energy consumed for RAM : 0.000603 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:42:41] Energy consumed for all GPUs : 0.002161 kWh. Total GPU Power : 20.35200470691146 W
# [codecarbon INFO @ 23:42:41] Energy consumed for all CPUs : 0.004999 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:42:42] 0.007762 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:42:56] Energy consumed for RAM : 0.000625 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:42:58] Energy consumed for all GPUs : 0.002235 kWh. Total GPU Power : 17.894188995229182 W
# [codecarbon INFO @ 23:42:58] Energy consumed for all CPUs : 0.005187 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:42:58] 0.008048 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:43:12] Energy consumed for RAM : 0.000647 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:43:14] Energy consumed for all GPUs : 0.002305 kWh. Total GPU Power : 17.804982733702037 W
# [codecarbon INFO @ 23:43:14] Energy consumed for all CPUs : 0.005364 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:43:14] 0.008315 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:43:28] Energy consumed for RAM : 0.000668 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:43:30] Energy consumed for all GPUs : 0.002389 kWh. Total GPU Power : 21.922476290155075 W
# [codecarbon INFO @ 23:43:30] Energy consumed for all CPUs : 0.005544 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:43:30] 0.008601 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:43:43] Energy consumed for RAM : 0.000686 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:43:45] Energy consumed for all GPUs : 0.002459 kWh. Total GPU Power : 19.945566344202316 W
# [codecarbon INFO @ 23:43:45] Energy consumed for all CPUs : 0.005706 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:43:45] 0.008851 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:43:58] Energy consumed for RAM : 0.000706 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:44:00] Energy consumed for all GPUs : 0.002531 kWh. Total GPU Power : 19.903545623383256 W
# [codecarbon INFO @ 23:44:00] Energy consumed for all CPUs : 0.005873 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:44:02] 0.009111 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:44:14] Energy consumed for RAM : 0.000727 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:44:17] Energy consumed for all GPUs : 0.002635 kWh. Total GPU Power : 26.789034704941898 W
# [codecarbon INFO @ 23:44:17] Energy consumed for all CPUs : 0.006053 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:44:18] 0.009416 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:44:30] Energy consumed for RAM : 0.000745 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:44:31] Energy consumed for all GPUs : 0.002702 kWh. Total GPU Power : 21.892779916964102 W
# [codecarbon INFO @ 23:44:31] Energy consumed for all CPUs : 0.006196 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:44:32] 0.009643 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:44:45] Energy consumed for RAM : 0.000766 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:44:48] Energy consumed for all GPUs : 0.002791 kWh. Total GPU Power : 21.67560051306908 W
# [codecarbon INFO @ 23:44:48] Energy consumed for all CPUs : 0.006385 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:44:49] 0.009941 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:45:01] Energy consumed for RAM : 0.000783 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:45:03] Energy consumed for all GPUs : 0.002871 kWh. Total GPU Power : 24.62765884564496 W
# [codecarbon INFO @ 23:45:03] Energy consumed for all CPUs : 0.006535 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:45:03] 0.010189 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:45:16] Energy consumed for RAM : 0.000802 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:45:19] Energy consumed for all GPUs : 0.002958 kWh. Total GPU Power : 23.591943476110636 W
# [codecarbon INFO @ 23:45:19] Energy consumed for all CPUs : 0.006706 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:45:20] 0.010466 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:45:32] Energy consumed for RAM : 0.000820 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:45:34] Energy consumed for all GPUs : 0.003050 kWh. Total GPU Power : 28.330726386035124 W
# [codecarbon INFO @ 23:45:34] Energy consumed for all CPUs : 0.006857 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:45:35] 0.010727 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:45:48] Energy consumed for RAM : 0.000840 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:45:51] Energy consumed for all GPUs : 0.003143 kWh. Total GPU Power : 24.005265070274245 W
# [codecarbon INFO @ 23:45:51] Energy consumed for all CPUs : 0.007039 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:45:52] 0.011022 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:46:03] Energy consumed for RAM : 0.000856 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:46:05] Energy consumed for all GPUs : 0.003210 kWh. Total GPU Power : 25.29060283370168 W
# [codecarbon INFO @ 23:46:05] Energy consumed for all CPUs : 0.007165 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:46:06] 0.011231 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:46:22] Energy consumed for RAM : 0.000880 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:46:24] Energy consumed for all GPUs : 0.003328 kWh. Total GPU Power : 28.749164981622346 W
# [codecarbon INFO @ 23:46:24] Energy consumed for all CPUs : 0.007362 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:46:27] 0.011570 kWh of electricity used since the beginning.
# SARIMA Predicted Values:
# 2024-04-01 00:00:00    2.722080
# 2024-04-01 01:00:00    2.618939
# 2024-04-01 02:00:00    2.601053
# 2024-04-01 03:00:00    2.954049
# 2024-04-01 04:00:00    3.337298
# 2024-04-01 05:00:00    3.874426
# 2024-04-01 06:00:00    4.549946
# 2024-04-01 07:00:00    4.732716
# 2024-04-01 08:00:00    4.947426
# 2024-04-01 09:00:00    4.810220
# 2024-04-01 10:00:00    4.569231
# 2024-04-01 11:00:00    3.615457
# 2024-04-01 12:00:00    2.859450
# 2024-04-01 13:00:00    2.088058
# 2024-04-01 14:00:00    1.343809
# 2024-04-01 15:00:00    0.713567
# 2024-04-01 16:00:00    0.105598
# 2024-04-01 17:00:00    0.184644
# 2024-04-01 18:00:00    0.153630
# 2024-04-01 19:00:00    0.747036
# 2024-04-01 20:00:00    1.240619
# 2024-04-01 21:00:00    1.877507
# 2024-04-01 22:00:00    2.315580
# 2024-04-01 23:00:00    2.512674
# Freq: H, Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Calculate and print the RMSE, MAE, and R-squared metrics
rmse = np.sqrt(mean_squared_error(actual_april_1_2024, sarima_forecast_mean))
mae = mean_absolute_error(actual_april_1_2024, sarima_forecast_mean)
r2 = r2_score(actual_april_1_2024, sarima_forecast_mean)

print("RMSE: ", rmse)
print("MAE: ", mae)
print("R-squared: ", r2)
# Out:
# RMSE:  0.5138936054482233
# MAE:  0.41630357656067546
# R-squared:  0.8819359467316278

# %%
# Plotting the SARIMA results with actual verified data for April 1st, 2024
plt.figure(figsize=(14, 7))
plt.plot(actual_april_1_2024.index, actual_april_1_2024, label='Actual Verified Water Level (ft)', color='blue')
plt.plot(sarima_forecast_mean.index, sarima_forecast_mean, label='SARIMA Forecasted Water Level (ft)', color='red', linestyle='--')
plt.fill_between(sarima_forecast_conf_int.index, sarima_forecast_conf_int.iloc[:, 0], sarima_forecast_conf_int.iloc[:, 1], color='red', alpha=0.3)
plt.title('SARIMA Forecast vs Actual Verified Water Levels on April 1, 2024')
plt.xlabel('Date')
plt.ylabel('Water Level (ft)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Insights from the Plot (SARIMA(1,1,2,24)):
# - This model also follows the trend of the verified data, suggesting the non-seasonal components are well-specified.
# - The wider confidence intervals around noon indicate increased uncertainty during these hours.
# - There's a noticeable deviation from the actual data in the afternoon hours where the model does not capture a dip in water levels seen in the actual data.

# %% [markdown]
# ### Conclusion:
#
# **Case 1: SARIMA(1,1,1,24)**
# - RMSE:  0.742
# - MAE:  0.577
# - R-squared:  0.754
#
# **Case 2: SARIMA(1,1,2,24)**
# - RMSE:  0.514
# - MAE:  0.416
# - R-squared:  0.882
#
# The SARIMA model with parameters (1,1,1,24) provides a forecast that remains consistently below the actual values, while the (1,1,2,24) model shows a slightly better capture of the fluctuations. However, both models underestimate the peaks and overestimate the troughs of the actual verified water levels to some extent. This could be due to inherent limitations of the SARIMA model when dealing with complex seasonal patterns or external influences not captured by the model.
#
# For both models, the forecast's confidence intervals suggest that while the direction of the water level changes is predicted, the magnitude of these changes is uncertain. Refining the model by tuning the seasonal parameters or incorporating exogenous variables (like weather or tidal information) could potentially improve the forecast's accuracy.
#
# In practice, while the SARIMA model provides a reasonable baseline forecast, it's important to incorporate domain-specific knowledge and additional data sources for more accurate predictions. It's also recommended to continuously validate and recalibrate the model with new data.

# %%
# Stop tracking and get emissions data
emissions = tracker.stop()
print(f"Estimated CO2 emissions for the computation: {emissions} kg")
# Out:
# [codecarbon INFO @ 23:46:36] Energy consumed for RAM : 0.000895 kWh. RAM Power : 5.884547710418702 W
# [codecarbon INFO @ 23:46:36] Energy consumed for all GPUs : 0.003392 kWh. Total GPU Power : 24.83220646799377 W
# [codecarbon INFO @ 23:46:36] Energy consumed for all CPUs : 0.007471 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:46:36] 0.011758 kWh of electricity used since the beginning.
# Estimated CO2 emissions for the computation: 0.004340429828979785 kg
