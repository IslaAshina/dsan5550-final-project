# %%
import pandas as pd

# Load the uploaded Excel file to examine its content
file_path = '../data/model performance.xlsx'
data = pd.read_excel(file_path)
data
# Out:
#                      Model Name   RMSE    MAE  R-squared
# 0              SARIMA(1,1,1,24)  0.742  0.577      0.754
# 1              SARIMA(1,1,2,24)  0.514  0.416      0.882
# 2                 Random Forest  0.112  0.088      0.994
# 3     Gradient Boosting Machine  0.118  0.095      0.994
# 4         LSTM - Original Model  0.691  0.587      0.786
# 5      LSTM - Adjust Complexity  0.584  0.495      0.847
# 6  LSTM - Hyperparameter Tuning  0.338  0.241      0.950

# %%
import matplotlib.pyplot as plt

# Setting up the figure and axes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Bar plot for RMSE
axes[0].bar(data['Model Name'], data['RMSE'], color='skyblue')
axes[0].set_title('RMSE by Model')
axes[0].set_ylabel('RMSE')
axes[0].set_xlabel('Model')
axes[0].set_xticklabels(data['Model Name'], rotation=45, ha='right')

# Bar plot for R-squared
axes[1].bar(data['Model Name'], data['R-squared'], color='salmon')
axes[1].set_title('R-squared by Model')
axes[1].set_ylabel('R-squared')
axes[1].set_xlabel('Model')
axes[1].set_xticklabels(data['Model Name'], rotation=45, ha='right')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# C:\Users\miran\AppData\Local\Temp\ipykernel_16708\1873657839.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(data['Model Name'], rotation=45, ha='right')
# C:\Users\miran\AppData\Local\Temp\ipykernel_16708\1873657839.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(data['Model Name'], rotation=45, ha='right')
